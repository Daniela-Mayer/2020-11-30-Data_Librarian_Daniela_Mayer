# %%
import json

# %%
url = "https://www.bibsonomy.org/json/search/Information%20Literacy?items=1000&duplicates=merged"

# %%
import requests

# %%
result = requests.get(url)

# %%
data = result.json()

# %%
type(data)
# Out:
# dict

# %%
print(len(data))
# Out:
# 3

# %%
print(data)
# Out:
# {'types': {'Bookmark': {'pluralLabel': 'Bookmarks'}, 'Publication': {'pluralLabel': 'Publications'}, 'GoldStandardPublication': {'pluralLabel': 'GoldStandardPublications'}, 'GoldStandardBookmark': {'pluralLabel': 'GoldStandardBookmarks'}, 'Tag': {'pluralLabel': 'Tags'}, 'User': {'pluralLabel': 'Users'}, 'Sphere': {'pluralLabel': 'Spheres'}}, 'properties': {'count': {'valueType': 'number'}, 'date': {'valueType': 'date'}, 'changeDate': {'valueType': 'date'}, 'url': {'valueType': 'url'}, 'id': {'valueType': 'url'}, 'tags': {'valueType': 'item'}, 'user': {'valueType': 'item'}}, 'items': [{'type': 'Bookmark', 'id': 'https://www.bibsonomy.org/url/6627d2a8e319a651dd96ab4cb09dcd25/blostben', 'tags': ['information_literacy', 'informationliteracy', 'value', 'informationskompetenz'], 'intraHash': '6627d2a8e319a651dd96ab4cb09dcd25', 'label': 'Determining the value of Information Literacy | Information Literacy', 'user': 'blostben', 'description': 'Determining the value of Information Literacy (D
# ...

# %%
from pprint import pprint
