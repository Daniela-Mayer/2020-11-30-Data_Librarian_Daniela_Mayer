# %%
import pandas as pd
df = pd.read_csv("../data/Library_Usage_Membership.csv")
df.head(10)
# Out:
#    Unnamed: 0  Patron Type Code Patron Type Definition  Total Checkouts  \
# 0           0                 0                  ADULT                0
# 1           1                 0                  ADULT               31
# 2           2                 0                  ADULT                0
# 3           3                 0                  ADULT                0
# 4           4                 0                  ADULT              126
# 5           5                 3                 SENIOR                0
# 6           6                 0                  ADULT             3002
# 7           7                 0                  ADULT                4
# 8           8                 0                  ADULT               20
# 9           9                 0                  ADULT                3
#
#    Total Renewals       Age Range Home Library Code Home Library Definition  \
# 0               0  20 to 24 years                P1                    Park
# ...
