# %%
#Wozu ist die erste Zeile (eine magische Funktion??) ??
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#Testdaten erstellen
x = range(1,10)

# %%
#Ein einfaches Streudiagramm erstellen
#"Solid" bei linestyle erzeugt die durchgängige Linie
plt.plot(x, x, c='black', linestyle='solid', marker='+')
