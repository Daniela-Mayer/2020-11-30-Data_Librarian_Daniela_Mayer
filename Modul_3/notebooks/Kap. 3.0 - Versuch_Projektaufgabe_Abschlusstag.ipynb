# %% [markdown]
# Liebe Ania, lieber Konrad, ich bin leider noch nicht so weit wie ich es gern wäre und bin nicht ganz zufrieden mit meinem Ergebnis. Auch  habe ich hier noch nicht die fehlenden Werte und Ausreißer beachtet. Ich muss noch viel üben, um die Statistiken zu erstellen, die ich gern hätte. Aber es macht Spaß! Dies ist also eher ein erster Versuch.

# %%
##[AL] Für den ersten Versuch ist das doch schon etwas. Die Detailfragen können wir sehr
#gerne morgen besprechen!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
sns.set()

df = pd.read_csv("../data/Library_Usage.csv")
df.head()
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 0                  ADULT                0               0
# 1                 0                  ADULT               31              22
# 2                 0                  ADULT                0               0
# 3                 0                  ADULT                0               0
# 4                 0                  ADULT              126              11
#
#         Age Range Home Library Code Home Library Definition  \
# 0  20 to 24 years                P1                    Park
# 1  25 to 34 years                S7                  Sunset
# 2  45 to 54 years                P1                    Park
# 3  25 to 34 years                 X            Main Library
# 4  45 to 54 years                M2                  Marina
#
#   Circulation Active Month Circulation Active Year Notice Preference Code  \
# ...

# %% [markdown]
# ## Wie viele Senioren und Kinder sind Kunden der San Francisco Public Library?

# %%
#Wenn wir nur die Kategorie "Seniors" betrachten
(df['Patron Type Definition'] == 'SENIOR').sum()
# Out:
# 41619

# %%
#Wenn wir nur die Kategorie "Juvenile" betrachten
(df['Patron Type Definition'] == 'JUVENILE').sum()
# Out:
# 59208

# %% [markdown]
# In der San Francisco Public Library sind 41619 Senioren und 59208 Kinder registriert.

# %%
## [AL] diese Fragestellung kann man unterschiedlich beantworten und hängt mit der
## Interpretation des Datensatzes zusammen. Nicht alle Merkmale unter 
## "Patron Type Definition" entsprechen einem Alter, daher könnte man 
## auch mit "Age Range"
## aber ist ok so

# %% [markdown]
# ## Bibliotheksbenutzung im Mission District

# %% [markdown]
# ### Wie viele Nutzer kommen aus dem Mission District?

# %%
print(len(df[df['Home Library Definition'] == 'Mission']))
# Out:
# 25443

# %% [markdown]
# ### Wie ist die Verteilung der Altersgruppen in den Zweigstellen?

# %%
pd.crosstab(
    df['Home Library Definition'],
    df['Age Range'],
)
# Out:
# Age Range                           0 to 9 years  10 to 19 years  \
# Home Library Definition
# Anza                                         765            1189
# Bayview/Linda Brooks-Burton                 1160            2008
# Bernal Heights                              1645            1538
# Branch Bookmobile (Excelsior)                  1               6
# Branch Bookmobile (Marina)                     0               0
# Branch Bookmobile (Sunset)                     1               5
# Branch Bookmobile (West Portal)                5              20
# Children's Bookmobile                        222             233
# Chinatown                                   1369            3132
# Eureka Valley/Harvey Milk Memorial           763             864
# Excelsior                                   2039            3869
# Glen Park                                   1212            1419
# Golden Gate Valley                           407             301
# ...

# %%
#Eigentlich wollte ich herausfinden, wie die Verteilung der Altersgruppen im Mission District sind.
#Aber da muss ich die nächsten Tage noch probieren. Falls ich es nicht schaffe, nehme ich es mit in den Präsenztag.

# %%
## [AL] Ok, können wir so machen!

# %% [markdown]
# ### Wie viele Nutzer möchten per Mail informiert werden?

# %%
print(len(df[df['Notice Preference Definition'] == 'email']))
# Out:
# 323937

# %%
#Wie alt sind diese Nutzer durchschnittlich im Vergleich zu Nutzern, die per Post informiert werden möchten?
#Diese Frage konnte ich leider noch nicht beantworten und werde es die nächsten Tage ebenfalls probieren

# %%
## [AL] Ok, können wir auch am Präsenztag machen!

# %% [markdown]
# ### Visualisierung der Ausleihzahlen im Vergleich zu den Anmeldejahren

# %%
sns.relplot(x='Total Checkouts', y='Year Patron Registered', data=df, aspect=1)

# %%
#An dieser Stelle muss ich vor der Präsentation noch die Jahre sortieren
#Hier lässt sich aber schon sehen, dass die Ausleihzahlen zurückgehen

# %%
## [AL] schön. Als Alternative kannst Du auch das nutzen:
sns.catplot( x="Year Patron Registered", y="Total Checkouts", data=df, aspect=4)

# %% [markdown]
# ### Was waren die anmeldeschwächsten und -stärksten Jahre von 2003 bis 2016?

# %%
df['Year Patron Registered'].value_counts().plot(kind='bar');

# %%
#Auch hier würde ich gern noch die Jahre sortieren, bevor ich es in die Präsentation mitnehme

# %%
# [AL] was genau meinst Du mit Jahre sortieren? Können wir ebenfalls am Präsenztag besprechen
