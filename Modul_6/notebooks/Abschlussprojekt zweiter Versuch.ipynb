# %% [markdown]
# #Aufgabe:
# Die Datei "AbschlussarbeitenReposit" (="Datei1") weist Abschlussarbeiten der HAW Hamburg nach und enthält Daten wie Autorin, Titel, Abstact, Jahr, ppn, etc.). Es fehlen dort die Namen der Betreuer*innen. Diese sollen ergänzt werden und können der Datei "AbschlussarbeitenCBS" (="Datei2") entnommen werden, welche z.B. Autor*in, Betreuer*innen, Titel, ppn enthält. Die Datensätze der beiden Dateien enthalten stimmen nur ungefähr überein, es gibt auch Datensätze die jeweils in nur einer der beiden Dateien auftauchen. D.h. ein einfaches Kopieren der Betreuer*innen-Spalte aus Datei2 und einfügen in Datei1 ist nicht möglich.
# Der Identifikator, anhand dessen eine eindeutige Zuordnung der Datensätze möglich ist, ist die ppn (Pica Produktionsnummer).

# %%
import pandas as pd

# %%
dfReposit = pd.read_excel("../data/AbschlussarbeitenReposit.xlsx")
dfCBS = pd.read_excel("../data/AbschlussarbeitenCBS.xlsx")

# %% [markdown]
# #Die erste Datei (Abschlussarbeiten Reposit) untersuchen

# %%
#Alle vorhandenen Spalten werden mit ...max_columns, None... angezeigt 
pd.set_option('max_columns', None)
dfReposit.head(10)
# Out:
#      id      collection dc.contributor.advisor dc.contributor.author  \
# 0  5132  20.500.12738/6                    NaN                   NaN
# 1  5360  20.500.12738/6                    NaN                   NaN
# 2  5134  20.500.12738/6                    NaN                   NaN
# 3  5376  20.500.12738/6                    NaN                   NaN
# 4  5377  20.500.12738/6                    NaN                   NaN
# 5  5136  20.500.12738/6                    NaN                   NaN
# 6  5378  20.500.12738/6                    NaN                   NaN
# 7  5379  20.500.12738/6                    NaN                   NaN
# 8  5369  20.500.12738/6                    NaN                   NaN
# 9  5368  20.500.12738/6                    NaN                   NaN
#
#                       dc.contributor.author[] dc.contributor.other[]  \
# 0               Discher, Annika::rp06916::600                    NaN
# 1           Eickhoff, Sebastian::rp07132::600                    NaN
# 2               Richter, Sandra::rp06917::600                    NaN
# 3               Knudsen, Martin::rp07147::600                    NaN
# 4            Zakarwal, Schafiqa::rp07148::600                    NaN
# 5               Sundas, Claudia::rp06919::600                    NaN
# 6              Jeretzky, Nicole::rp07149::600                    NaN
# 7  Tamancoldi Lechte, Yasmin N.::rp07150::600                    NaN
# 8              Hilbig, Svetlana::rp07141::600                    NaN
# 9              Liedtke, Andreas::rp07140::600                    NaN
#
#   dc.contributorCorporate.other[] dc.date.created  dc.date.created[]  \
# 0                             NaN             NaN             2010.0
# 1                             NaN             NaN             2011.0
# 2                             NaN             NaN             2010.0
# 3                             NaN             NaN             2011.0
# 4                             NaN             NaN             2011.0
# 5                             NaN             NaN             2006.0
# 6                             NaN             NaN             2011.0
# 7                             NaN             NaN             2011.0
# 8                             NaN             NaN             2011.0
# 9                             NaN             NaN             2011.0
#
#   dc.date.issued dc.date.issued[] dc.description.abstract[]  \
# 0            NaN       2010-06-28                       NaN
# 1            NaN       2011-06-22                       NaN
# 2            NaN       2010-06-28                       NaN
# 3            NaN       2011-06-30                       NaN
# 4            NaN       2011-06-30                       NaN
# 5            NaN       2006-10-06                       NaN
# 6            NaN       2011-06-30   kein Abstract vorhanden
# 7            NaN       2011-06-30                       NaN
# 8            NaN       2011-06-29                       NaN
# 9            NaN       2011-06-28                       NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              dc.description.abstract[de]  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                kein Abstract vorhanden
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          In dieser Arbeit wird ein Sensor-Aktor-System entwickelt, welches auf mobilen Robotern zum Einsatz kommen kann. Es werden die Grundlagen für dieses Projekt analysiert und daraus die entsprechenden Anforderungen an das System erstellt. Der Katalog aus Anforderungen stellt die Grundlage für das folgende Design der Hardware und Software dar. Der Schwerpunkt liegt im Bereich Softwarearchitektur, welche auf dem Mikrocontroller implementiert wird.
# 2                    Die vorliegende Bachelorarbeit beschäftigt sich mit der Frage, wie sich der Einfluss eines Hamburger Modelprojektes auf die Mitarbeiter/-innenzufriedenheit und –gesundheit ausgewirkt hat. Das Ziel dieser Arbeitet ist es, dies durch die Daten der Mitarbeiter/-innen, die Auskunft über ihre Zufriedenheit und Gesundheit geben, herauszufinden. Die Daten stammen aus der Eingangs- und Abschlussbefragung des Projekts „ Kitas fit für die Zukunft“. Um die Daten vergleichen zu können wurden aus anderen Studien bundesweite Referenzwerte zusammengestellt. Im zweiten und dritten Abschnitt wird in dieser Arbeit\nüber den derzeitigen Forschungsstand und das Projekt „Kitas fit für die Zukunft“ berichtet.\nAnschließend wird im vierten Abschnitt der Inhalt und Aufbau des Fragebogens\nbeschrieben und tabellarisch dargestellt. Des Weiteren werden die zusammengestellten Referenzwerte aufgezeigt und das Vorgehen geschildert. Der fünfte und sechste Abschnitt befasst sich mit dem Rücklauf und der Stichprobenbeschreibung der befragten Mitarbeiter/-innen. Die darauf folgenden Abschnitte zeigen die Ergebnisse der Eingangsund Abschlussbefragung, die Auskunft über die Mitarbeiter/-innenzufriedenheit und –gesundheit geben. Zum Schluss folgen eine kurze Diskussion und das Fazit.
# 3                                                                                                                                                                                                                                                                                          Gegenstand dieser Arbeit ist die Planung und Entwicklung einer prototypischen Smartphone-Applikation zur Interaktion mit einem bestehenden Web 2.0 Angebot. Nach einer kurzen Vorstellung der vorhandenen Plattform „Sempr“ wird der geplante Funktionsumfang der zu entwickelnden Software „Sempr-Mobile“ definiert und anhand von UML veranschaulicht. Um den Entwicklungsauwand einzuschränken wurde ferner eine der am Markt vorhandenen Smartphone-Plattformen ausgewählt und diese Entscheidung anhand verschiedener Kriterien begründet. Anschliessend werden Anwendungsstruktur sowie Implementierung näher erläutert und mit Beispielen veranschaulicht. Ein weiterer Arbeitsschwerpunkt war die Integration des Projektes in den Softwareentwicklungsprozess der Firma Linkwerk GmbH. Im letzten Abschnitt wird eine Bilanz aus den geleisteten Ergebnissen gezogen und die fertige Anwendung kritisch bewertet. Auch werden hier zukünftige Entwicklungsmöglichkeiten sowie Verbesserungspotenziale der Software näher beleuchtet.
# 4                                                                                             Gegenstand der vorliegenden Arbeit ist die Entwicklung einer neuen kulturellen Identität, durch Beeinflussung von audiovisuellen Medien. Um Einstellungen und Daten von der Zielgruppe zu erhalten, wurden 40 Hamburger Bürger im Alter zwischen 14 und 25 Jahren, mit afghanischer Herkunft, befragt und ausgewertet. In der Umfrage wurde berücksichtigt, dass ein Großteil der Zielgruppe, Nachkommen von afghanischen Flüchtlingen sind, dass sie nicht freiwillig nach Deutschland gekommen sind und dass sie in Afghanistan ethnische Konflikte hatten. Weiterhin wurde in einer vorrausgehenden Bestandsaufnahme der afghanischen Gemeinschaft in Hamburg ihre Diaspora Situation, ihre islamische Religion und der Einfluss von Massenmedien auf junge heranwachsende Migranten analysiert. Dabei unterstützten mehrere leitfadengestützte Interviews mit drei afghanischen Müttern aus Hamburg die Einstellungen und Entwicklungen der Zielpersonen. In einem abschließenden Experteninterview, bei dem die Ergebnisse einer Expertin gezeigt wurden, werden die Ergebnisse nach Ursache und Lösungsmöglichkeiten analysiert. Die vorliegende Arbeit berücksichtigt dabei die Situation, in welcher sich die Zielgruppe befindet.
# 5                                                                                                                                                                                                                                                           Interkulturelles Verstehen kann ebenso wie Medienkompetenz mittels Projekten der aktiven Medienarbeit gefördert werden. Der künstlerische und handelnde Umgang mit einem Medium übt nicht nur technische und gestalterische Fähigkeiten, er bietet auch die Möglichkeit, persönliche Inhalte zu thematisieren. In einem Videoprojekt können so kulturelle Aspekte der Lebenswelt visualisiert und anschließend reflektiert werden. Gerade bei Kindern bietet sich eine künstlerisch-gestalterische Auseinandersetzung mit dem Thema Multikulturalität an. In den wenigsten vorhandenen medienpädagogischen Projekten wird aber interkulturelles Lernen explizit angesprochen.\nZiel dieser Arbeit ist es, ein medienpädagogisches Projekt auf Grundlage einer ausreichendentheoretischen Betrachtung zu konzipieren, dass neben den verschiedenen Fähigkeiten,die im Begriff der Medienkompetenz gebündelt sind, auch interkulturelles Lernen fördert. Es soll weiterhin dazu beitragen, mehr Kinder als bisher an den Möglichkeiten der aktiven Medienarbeit zu beteiligen.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    NaN
# 7                                                                                                                                                                                                                                                                                                                                                                                                    Im theoretischen Teil dieser Arbeit wurden Eigenschaften des Web 2.0 und des da-zugehörenden Social Web vorgestellt. Die Erläuterungen dienen als Basis für eine detail-lierte Analyse der ausgewählten Plattformen und ihrer Funktion im Social Media Marketing. Die Resultate helfen dabei, den Begriff zu definieren und die Umsetzungsmöglichkei-ten darzustellen. Mithilfe einer Stärken-Schwächen-Analyse werden die Plattformen auf ihre Eignung für das Erreichen von angestrebten Kommunikationszielen untersucht. \nIm praktischen Teil der Arbeit wird die online Kommunikation von Schwarze Dose 28 und die des Marktführers Red Bull analysiert. Dabei werden Kommunikationsstärken und –schwächen erkannt und beschrieben. Auf Basis der erhobenen Daten über das Web 2.0-Umfeld und der internen Faktoren des Unternehmens konnte eine SWOT-Analyse er-stellt und zur Verbesserung der aktuellen Promotion-Strategie
# 8  In den Zeiten der allgemeinen Verbreitung von Web 2.0-Technologien mit ihren unbegrenzten und kostengünstigen Kommunikationsmöglichkeiten haben Telekommunikationsunternehmen überlebenswichtige Herausforderungen zu meistern. Auf der Suche nach neuen Einkommensquellen und Kundensegmenten öffnen sie ihre Plattformen für Entwickler und bauen begleitende Web-Portale und Communities auf. Die zentrale Frage ist dabei, wie relevant diese Produkte für ein Telekommunikationsunternehmen sind und wie zukunfts- und konkurrenzfähig sie aufgestellt sind. Die vorliegende Arbeit beschäftigt sich  mit der Analyse der aktuellen Situation auf dem sich im Stundentakt verändernden Markt mobiler und neuer Web-Technologien und setzt sich mit Erfolgskriterien eines Entwickler-Angebots von Telcos auseinander. Zu diesem Zweck wurde eine Benchmarking-Untersuchung durchgeführt, im Laufe welcher Geschäftsmodelle diverser Entwickler-Portale unter mehreren Aspekten analysiert wurden. Die dabei ermittelten Erfolgsfaktoren sowie Schwächen und Nachteile einiger Angebote wurden zur Bestimmung des aktuellen Marktstandes einer der wenigen Telco-Community im deutschsprachigen Raum – „Developer Garden“ und zur Ausarbeitung von Empfehlungen für die Weiterentwicklungs- und Verbesserungsmaßnahmen verwendet.
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               In der vorliegenden Arbeit wird ein Verfahren, zur Lokalisierung autonomer mobiler Roboter, auf Basis des SURF-Merkmalsextraktor und optimaler SURF-Marken, entwickelt. Autonome mobile System, ausgestattet mit einer Kamera, sollen ihre Position anhand der verwendeten Positionsmarken bestimmen können. Das entwickelte Verfahren soll so robust wie möglich gegenüber Störeffekten wie Bildrauschen, Belichtungsänderungen und Perspektivischen Verzerrungen sein.
#
#                                                                                                                                                                                                                                                                                                                                                                                            dc.description.abstract[en]  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                  NaN
# 1                      This thesis deals with the development of an Sensor-Actor-System, which will be used in mobile robotics. The initial situation is analyzed and according to this the requirements are generated. The list of requirements is the basis for the following design proccess for hardware and software. The main focus is on the software architecture, which is implemented on the microcontroller
# 2                                                                                                                                                                                                                                                                                                                                                                                                                  NaN
# 3                                                                                                                                                                                                                                                                                                                                                                                                                  NaN
# 4                                                                                                                                                                                                                                                                                                                                                                                                                  NaN
# 5                                                                                                                                                                                                                                                                                                                                                                                                                  NaN
# 6                                                                                                                                                                                                                                                                                                                                                                                                                  NaN
# 7                                                                                                                                                                                                                                                                                                                                                                                                                  NaN
# 8                                                                                                                                                                                                                                                                                                                                                                                                                  NaN
# 9  This paper describes a methode for localization of autonomous mobile robots. Based on the SURF feature detector and optimal SURF-Markers. Autonomous mobile robots equipped with a camera, shall be able to estimate their position from the used landmarks. The developed procedure target to be as robust as possible against negative effects like image noise, illumination changes and perspective distortion.
#
#   dc.description.abstract[en_US] dc.description.abstract[mis]  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
# 5                            NaN                          NaN
# 6                            NaN                          NaN
# 7                            NaN                          NaN
# 8                            NaN                          NaN
# 9                            NaN                          NaN
#
#                                          dc.identifier.uri  \
# 0  https://reposit.haw-hamburg.de/handle/20.500.12738/5130
# 1  https://reposit.haw-hamburg.de/handle/20.500.12738/5358
# 2  https://reposit.haw-hamburg.de/handle/20.500.12738/5132
# 3  https://reposit.haw-hamburg.de/handle/20.500.12738/5374
# 4  https://reposit.haw-hamburg.de/handle/20.500.12738/5375
# 5  https://reposit.haw-hamburg.de/handle/20.500.12738/5134
# 6  https://reposit.haw-hamburg.de/handle/20.500.12738/5376
# 7  https://reposit.haw-hamburg.de/handle/20.500.12738/5377
# 8  https://reposit.haw-hamburg.de/handle/20.500.12738/5367
# 9  https://reposit.haw-hamburg.de/handle/20.500.12738/5366
#
#   dc.identifier.urn[] dc.language.iso[de] dc.language.iso[en]  \
# 0                 NaN                  de                 NaN
# 1                 NaN                  de                 NaN
# 2                 NaN                  de                 NaN
# 3                 NaN                  de                 NaN
# 4                 NaN                  de                 NaN
# 5                 NaN                  de                 NaN
# 6                 NaN                  de                 NaN
# 7                 NaN                  de                 NaN
# 8                 NaN                  de                 NaN
# 9                 NaN                  de                 NaN
#
#   dc.language.iso[en_US] dc.relation.isreplacedby dc.rights.cc[]  \
# 0                    NaN                      NaN            NaN
# 1                    NaN                      NaN            NaN
# 2                    NaN                      NaN            NaN
# 3                    NaN                      NaN            NaN
# 4                    NaN                      NaN            NaN
# 5                    NaN                      NaN            NaN
# 6                    NaN                      NaN            NaN
# 7                    NaN                      NaN            NaN
# 8                    NaN                      NaN            NaN
# 9                    NaN                      NaN            NaN
#
#   dc.rights.cc[en_US] dc.subject.ddc  \
# 0                 NaN            NaN
# 1                 NaN            NaN
# 2                 NaN            NaN
# 3                 NaN            NaN
# 4                 NaN            NaN
# 5                 NaN            NaN
# 6                 NaN            NaN
# 7                 NaN            NaN
# 8                 NaN            NaN
# 9                 NaN            NaN
#
#                                       dc.subject.ddc[] dc.subject.ddc[en_US]  \
# 0  360 Soziale Probleme, Sozialdienste, Versicherungen                   NaN
# 1                                       004 Informatik                   NaN
# 2  300 Sozialwissenschaften, Soziologie, Anthropologie                   NaN
# 3        020 Bibliotheks- und Informationswissenschaft                   NaN
# 4        020 Bibliotheks- und Informationswissenschaft                   NaN
# 5                                                  NaN                   NaN
# 6        020 Bibliotheks- und Informationswissenschaft                   NaN
# 7        020 Bibliotheks- und Informationswissenschaft                   NaN
# 8        020 Bibliotheks- und Informationswissenschaft                   NaN
# 9                                       004 Informatik                   NaN
#
#   dc.subject.gnd  \
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
#
#                                                                         dc.subject.gnd[]  \
# 0                                           Essstörung||Mädchen||Prävention||Entwicklung
# 1                                                                   Eingebettetes System
# 2                              Kindertagesstätte||Mitarbeiter||Zufriedenheit||Gesundheit
# 3                                                   Mobiles Internet||World Wide Web 2.0
# 4                                                Medienkonsum||Afghanischer Jugendlicher
# 5  Interkulturelle Erziehung||Interkulturelle Sozialarbeit||Medienpädagogik||Video||Kind
# 6                                                 Marke||Medienkonsum||Kind <5-12 Jahre>
# 7                                                                         Soziomarketing
# 8                             World Wide Web 2.0||Telekommunikationsdienst||Benchmarking
# 9                                                                                Roboter
#
#      dc.subject[de] dc.subject[en] dc.subject[en_US] dc.title.alternative[en]  \
# 0               NaN            NaN               NaN                      NaN
# 1               NaN            NaN               NaN                      NaN
# 2               NaN            NaN               NaN                      NaN
# 3               NaN            NaN               NaN                      NaN
# 4               NaN            NaN               NaN                      NaN
# 5               NaN            NaN               NaN                      NaN
# 6               NaN            NaN               NaN                      NaN
# 7  Schwarze Dose 28            NaN               NaN                      NaN
# 8  Developer Garden            NaN               NaN                      NaN
# 9        SURF||SIFT            NaN               NaN                      NaN
#
#                                                                                                                                                 dc.title[de]  \
# 0                       Zur Bedeutung der Gesellschaft für die Entwicklung von Essstörungen und deren Reflektion in mädchenspezifischen Präventionskonzepten
# 1                                                                                                       Ein modulares Sensor-Aktor-System für mobile Robotik
# 2  Gesundheitsauswirkungen des Setting-Ansatzes in Kitas: Der Einfluss eines Hamburger Modellprojektes auf die MitarbeiterInnenzufriedenheit und -gesundheit
# 3                                                             Realisierung eines mobilen Informationsdienstes durch eine Web 2.0 Applikation auf Smartphones
# 4  Afghanische Kultur ade- Interviewgestützte Befragung afghanischer Jugendlicher zu Einfluss und Wirkung audiovisueller Medien auf die kulturelle Identität
# 5                                                Modellprojekt „filmreif“ : Konzeption eines interkulturellen medienpädagogischen Videoprojektes mit Kindern
# 6                                                          Magie der Marke : Rezeptionsstudie zu Charakter, Präsenz und Wirkung von Medienmarken bei Kindern
# 7              Social Media Marketing in der Kommunikationspolitik : Fallbeispiel SWOT-Analyse zur Verbesserung der Promotion-Strategie von Schwarze Dose 28
# 8      Entwicklerportal als Geschäftsmodell 2.0: seine Relevanz und Zukunftsfähigkeit für Telekommunikationsunternehmen (am Beispiel von „Developer Garden”)
# 9                        Realisierung eines robusten Verfahrens zur Identifikation von Positionsmarken unter Verwendung von Bildverarbeitung in Videobildern
#
#   dc.title[en] dc.title[en_US] dc.type                  dc.type.casrai  \
# 0          NaN             NaN     NaN  Supervised Student Publication
# 1          NaN             NaN     NaN  Supervised Student Publication
# 2          NaN             NaN     NaN  Supervised Student Publication
# 3          NaN             NaN     NaN  Supervised Student Publication
# 4          NaN             NaN     NaN  Supervised Student Publication
# 5          NaN             NaN     NaN  Supervised Student Publication
# 6          NaN             NaN     NaN  Supervised Student Publication
# 7          NaN             NaN     NaN  Supervised Student Publication
# 8          NaN             NaN     NaN  Supervised Student Publication
# 9          NaN             NaN     NaN  Supervised Student Publication
#
#      dc.type.dini  dc.type.driver dc.type.status  \
# 0  bachelorThesis  bachelorThesis            NaN
# 1  bachelorThesis  bachelorThesis            NaN
# 2  bachelorThesis  bachelorThesis            NaN
# 3  bachelorThesis  bachelorThesis            NaN
# 4  bachelorThesis  bachelorThesis            NaN
# 5    masterThesis    masterThesis            NaN
# 6  bachelorThesis  bachelorThesis            NaN
# 7  bachelorThesis  bachelorThesis            NaN
# 8  bachelorThesis  bachelorThesis            NaN
# 9  bachelorThesis  bachelorThesis            NaN
#
#                           dc.type.status[] dc.type.status[en_US]  \
# 0  info:eu-repo/semantics/publishedVersion                   NaN
# 1  info:eu-repo/semantics/publishedVersion                   NaN
# 2  info:eu-repo/semantics/publishedVersion                   NaN
# 3  info:eu-repo/semantics/publishedVersion                   NaN
# 4  info:eu-repo/semantics/publishedVersion                   NaN
# 5  info:eu-repo/semantics/publishedVersion                   NaN
# 6  info:eu-repo/semantics/publishedVersion                   NaN
# 7  info:eu-repo/semantics/publishedVersion                   NaN
# 8  info:eu-repo/semantics/publishedVersion                   NaN
# 9  info:eu-repo/semantics/publishedVersion                   NaN
#
#   dc.type.thesis dc.type.thesis[] dc.type.thesis[en_US] dc.type[]  \
# 0            NaN   bachelorThesis                   NaN    Thesis
# 1            NaN   bachelorThesis                   NaN    Thesis
# 2            NaN   bachelorThesis                   NaN    Thesis
# 3            NaN   bachelorThesis                   NaN    Thesis
# 4            NaN   bachelorThesis                   NaN    Thesis
# 5            NaN     masterThesis                   NaN    Thesis
# 6            NaN   bachelorThesis                   NaN    Thesis
# 7            NaN   bachelorThesis                   NaN    Thesis
# 8            NaN   bachelorThesis                   NaN    Thesis
# 9            NaN   bachelorThesis                   NaN    Thesis
#
#   dc.type[en_US] dcterms.DCMIType local.comment openaire.rights  \
# 0            NaN             Text           NaN             NaN
# 1            NaN             Text           NaN             NaN
# 2            NaN             Text           NaN             NaN
# 3            NaN             Text           NaN             NaN
# 4            NaN             Text           NaN             NaN
# 5            NaN             Text           NaN             NaN
# 6            NaN             Text           NaN             NaN
# 7            NaN             Text           NaN             NaN
# 8            NaN             Text           NaN             NaN
# 9            NaN             Text           NaN             NaN
#
#                           openaire.rights[] openaire.rights[en_US]  \
# 0  http://purl.org/coar/access_right/c_abf2                    NaN
# 1  http://purl.org/coar/access_right/c_abf2                    NaN
# 2  http://purl.org/coar/access_right/c_abf2                    NaN
# 3  http://purl.org/coar/access_right/c_abf2                    NaN
# 4  http://purl.org/coar/access_right/c_abf2                    NaN
# 5  http://purl.org/coar/access_right/c_abf2                    NaN
# 6  http://purl.org/coar/access_right/c_abf2                    NaN
# 7  http://purl.org/coar/access_right/c_abf2                    NaN
# 8  http://purl.org/coar/access_right/c_abf2                    NaN
# 9  http://purl.org/coar/access_right/c_abf2                    NaN
#
#   thesis.grantor.department  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
#
#                           thesis.grantor.department[]  \
# 0             Department Soziale Arbeit::ou00050::600
# 1                 Department Informatik::ou00045::600
# 2  Department Gesundheitswissenschaften::ou00038::600
# 3                Department Information::ou00034::600
# 4                Department Information::ou00034::600
# 5             Department Soziale Arbeit::ou00050::600
# 6                Department Information::ou00034::600
# 7                Department Information::ou00034::600
# 8                Department Information::ou00034::600
# 9                 Department Informatik::ou00045::600
#
#   thesis.grantor.department[en_US] thesis.grantor.place  \
# 0                              NaN                  NaN
# 1                              NaN                  NaN
# 2                              NaN                  NaN
# 3                              NaN                  NaN
# 4                              NaN                  NaN
# 5                              NaN                  NaN
# 6                              NaN                  NaN
# 7                              NaN                  NaN
# 8                              NaN                  NaN
# 9                              NaN                  NaN
#
#   thesis.grantor.place[] thesis.grantor.universityOrInstitution  \
# 0                Hamburg                                    NaN
# 1                Hamburg                                    NaN
# 2                Hamburg                                    NaN
# 3                Hamburg                                    NaN
# 4                Hamburg                                    NaN
# 5                Hamburg                                    NaN
# 6                Hamburg                                    NaN
# 7                Hamburg                                    NaN
# 8                Hamburg                                    NaN
# 9                Hamburg                                    NaN
#
#                          thesis.grantor.universityOrInstitution[]  \
# 0  Hochschule für angewandte Wissenschaften Hamburg::ou00001::600
# 1  Hochschule für angewandte Wissenschaften Hamburg::ou00001::600
# 2  Hochschule für angewandte Wissenschaften Hamburg::ou00001::600
# 3  Hochschule für angewandte Wissenschaften Hamburg::ou00001::600
# 4  Hochschule für angewandte Wissenschaften Hamburg::ou00001::600
# 5  Hochschule für angewandte Wissenschaften Hamburg::ou00001::600
# 6  Hochschule für angewandte Wissenschaften Hamburg::ou00001::600
# 7  Hochschule für angewandte Wissenschaften Hamburg::ou00001::600
# 8  Hochschule für angewandte Wissenschaften Hamburg::ou00001::600
# 9  Hochschule für angewandte Wissenschaften Hamburg::ou00001::600
#
#   thesis.grantor.universityOrInstitution[en_US] tuhh.contributor.referee  \
# 0                                           NaN                      NaN
# 1                                           NaN                      NaN
# 2                                           NaN                      NaN
# 3                                           NaN                      NaN
# 4                                           NaN                      NaN
# 5                                           NaN                      NaN
# 6                                           NaN                      NaN
# 7                                           NaN                      NaN
# 8                                           NaN                      NaN
# 9                                           NaN                      NaN
#
#    tuhh.gvk.ppn tuhh.gvk.ppn[] tuhh.note.extern tuhh.note.extern[]  \
# 0           NaN      630150826              NaN       publ-mit-pod
# 1           NaN      662632974              NaN       publ-mit-pod
# 2           NaN      630155089              NaN       publ-mit-pod
# 3           NaN      663400872              NaN       publ-mit-pod
# 4           NaN      66340200X              NaN       publ-mit-pod
# 5           NaN      51844483X              NaN                NaN
# 6           NaN      663403200              NaN                NaN
# 7           NaN      663404932              NaN       publ-mit-pod
# 8           NaN      663322782              NaN       publ-mit-pod
# 9           NaN      663207673              NaN       publ-mit-pod
#
#    tuhh.note.intern  tuhh.note.intern[] tuhh.oai.show[en_US]  tuhh.opus.id  \
# 0               NaN                 1.0                 True           NaN
# 1               NaN                 1.0                 True           NaN
# 2               NaN                 1.0                 True           NaN
# 3               NaN                 1.0                 True           NaN
# 4               NaN                 1.0                 True           NaN
# 5               NaN                 NaN                 True           NaN
# 6               NaN                 1.0                 True           NaN
# 7               NaN                 1.0                 True           NaN
# 8               NaN                 1.0                 True           NaN
# 9               NaN                 1.0                 True           NaN
#
#    tuhh.opus.id[] tuhh.publication.institute  \
# 0          1025.0                        NaN
# 1          1268.0                        NaN
# 2          1027.0                        NaN
# 3          1284.0                        NaN
# 4          1285.0                        NaN
# 5           103.0                        NaN
# 6          1286.0                        NaN
# 7          1287.0                        NaN
# 8          1276.0                        NaN
# 9          1275.0                        NaN
#
#                          tuhh.publication.institute[]  \
# 0             Department Soziale Arbeit::ou00050::600
# 1                 Department Informatik::ou00045::600
# 2  Department Gesundheitswissenschaften::ou00038::600
# 3                Department Information::ou00034::600
# 4                Department Information::ou00034::600
# 5             Department Soziale Arbeit::ou00050::600
# 6                Department Information::ou00034::600
# 7                Department Information::ou00034::600
# 8                Department Information::ou00034::600
# 9                 Department Informatik::ou00045::600
#
#   tuhh.publication.institute[en_US]   tuhh.type.opus tuhh.uploader.email  \
# 0                               NaN  Bachelor Thesis                 NaN
# 1                               NaN  Bachelor Thesis                 NaN
# 2                               NaN  Bachelor Thesis                 NaN
# 3                               NaN  Bachelor Thesis                 NaN
# 4                               NaN  Bachelor Thesis                 NaN
# 5                               NaN     Masterarbeit                 NaN
# 6                               NaN  Bachelor Thesis                 NaN
# 7                               NaN  Bachelor Thesis                 NaN
# 8                               NaN  Bachelor Thesis                 NaN
# 9                               NaN  Bachelor Thesis                 NaN
#
#                    tuhh.uploader.email[]
# 0       kerstin.hauschild@haw-hamburg.de
# 1                                      @
# 2           susanne.gassl@haw-hamburg.de
# 3       detlev.dannenberg@haw-hamburg.de
# 4       detlev.dannenberg@haw-hamburg.de
# 5  kerstin.hauschild@hibs.haw-hamburg.de
# 6       detlev.dannenberg@haw-hamburg.de
# 7       detlev.dannenberg@haw-hamburg.de
# 8       detlev.dannenberg@haw-hamburg.de
# 9                                      @

# %%
dfReposit.columns
# Out:
# Index(['id', 'collection', 'dc.contributor.advisor', 'dc.contributor.author',
#        'dc.contributor.author[]', 'dc.contributor.other[]',
#        'dc.contributorCorporate.other[]', 'dc.date.created',
#        'dc.date.created[]', 'dc.date.issued', 'dc.date.issued[]',
#        'dc.description.abstract[]', 'dc.description.abstract[de]',
#        'dc.description.abstract[en]', 'dc.description.abstract[en_US]',
#        'dc.description.abstract[mis]', 'dc.identifier.uri',
#        'dc.identifier.urn[]', 'dc.language.iso[de]', 'dc.language.iso[en]',
#        'dc.language.iso[en_US]', 'dc.relation.isreplacedby', 'dc.rights.cc[]',
#        'dc.rights.cc[en_US]', 'dc.subject.ddc', 'dc.subject.ddc[]',
#        'dc.subject.ddc[en_US]', 'dc.subject.gnd', 'dc.subject.gnd[]',
#        'dc.subject[de]', 'dc.subject[en]', 'dc.subject[en_US]',
#        'dc.title.alternative[en]', 'dc.title[de]', 'dc.title[en]',
#        'dc.title[en_US]', 'dc.type', 'dc.type.casrai', 'dc.type.dini',
#        'dc.type.driver', 'dc.type.status', 'dc.type.status[]',
#        'dc.type.status[en_US]', 'dc.type.thesis', 'dc.type.thesis[]',
#        'dc.type.thesis[en_US]', 'dc.type[]', 'dc.type[en_US]',
#        'dcterms.DCMIType', 'local.comment', 'openaire.rights',
#        'openaire.rights[]', 'openaire.rights[en_US]',
#        'thesis.grantor.department', 'thesis.grantor.department[]',
#        'thesis.grantor.department[en_US]', 'thesis.grantor.place',
#        'thesis.grantor.place[]', 'thesis.grantor.universityOrInstitution',
#        'thesis.grantor.universityOrInstitution[]',
#        'thesis.grantor.universityOrInstitution[en_US]',
#        'tuhh.contributor.referee', 'tuhh.gvk.ppn', 'tuhh.gvk.ppn[]',
#        'tuhh.note.extern', 'tuhh.note.extern[]', 'tuhh.note.intern',
#        'tuhh.note.intern[]', 'tuhh.oai.show[en_US]', 'tuhh.opus.id',
#        'tuhh.opus.id[]', 'tuhh.publication.institute',
#        'tuhh.publication.institute[]', 'tuhh.publication.institute[en_US]',
#        'tuhh.type.opus', 'tuhh.uploader.email', 'tuhh.uploader.email[]'],
#       dtype='object')

# %%
#Für die spätere Weiterverarbeitng müssen nur die Spalten id und collection erhalten bleiben. Die Betreuer*innen
#sollen in die Spalten "dc.contributor.advisor' bzw. 'tuhh.contributor.referee'. Zur Kontrolle
#sollen auch Autor*in (Spalte 'dc.contributor.author[]') und der Titel (Spalte 'dc.title[de]' bzw.
# 'dc.title[en]') bleiben. Und natürlich die Spalte mit dem Identifikator (ppn): 'tuhh.gvk.ppn[]'
#D.h. es sollen insg. 8 Spalten bestehen bleibne. 
#Die nicht benötigten Spalten mit "drop" löschen und Ergebnis in eine neue Variable schreiben:
dfReposit8Spalten = dfReposit.drop(['dc.contributor.author', 'dc.contributor.other[]',
       'dc.contributorCorporate.other[]', 'dc.date.created',
       'dc.date.created[]', 'dc.date.issued', 'dc.date.issued[]',
       'dc.description.abstract[]', 'dc.description.abstract[de]',
       'dc.description.abstract[en]', 'dc.description.abstract[en_US]',
       'dc.description.abstract[mis]', 'dc.identifier.uri',
       'dc.identifier.urn[]', 'dc.language.iso[de]', 'dc.language.iso[en]',
       'dc.language.iso[en_US]', 'dc.relation.isreplacedby', 'dc.rights.cc[]',
       'dc.rights.cc[en_US]', 'dc.subject.ddc', 'dc.subject.ddc[]',
       'dc.subject.ddc[en_US]', 'dc.subject.gnd', 'dc.subject.gnd[]',
       'dc.subject[de]', 'dc.subject[en]', 'dc.subject[en_US]',
       'dc.title.alternative[en]',
       'dc.title[en_US]', 'dc.type', 'dc.type.casrai', 'dc.type.dini',
       'dc.type.driver', 'dc.type.status', 'dc.type.status[]',
       'dc.type.status[en_US]', 'dc.type.thesis', 'dc.type.thesis[]',
       'dc.type.thesis[en_US]', 'dc.type[]', 'dc.type[en_US]',
       'dcterms.DCMIType', 'local.comment', 'openaire.rights',
       'openaire.rights[]', 'openaire.rights[en_US]',
       'thesis.grantor.department', 'thesis.grantor.department[]',
       'thesis.grantor.department[en_US]', 'thesis.grantor.place',
       'thesis.grantor.place[]', 'thesis.grantor.universityOrInstitution',
       'thesis.grantor.universityOrInstitution[]',
       'thesis.grantor.universityOrInstitution[en_US]',
        'tuhh.gvk.ppn', 'tuhh.note.extern', 'tuhh.note.extern[]', 'tuhh.note.intern',
       'tuhh.note.intern[]', 'tuhh.oai.show[en_US]', 'tuhh.opus.id',
       'tuhh.opus.id[]', 'tuhh.publication.institute',
       'tuhh.publication.institute[]', 'tuhh.publication.institute[en_US]',
       'tuhh.type.opus', 'tuhh.uploader.email', 'tuhh.uploader.email[]'], axis=1)

# %%
dfReposit8Spalten.head()
# Out:
#      id      collection dc.contributor.advisor  \
# 0  5132  20.500.12738/6                    NaN
# 1  5360  20.500.12738/6                    NaN
# 2  5134  20.500.12738/6                    NaN
# 3  5376  20.500.12738/6                    NaN
# 4  5377  20.500.12738/6                    NaN
#
#              dc.contributor.author[]  \
# 0      Discher, Annika::rp06916::600
# 1  Eickhoff, Sebastian::rp07132::600
# 2      Richter, Sandra::rp06917::600
# 3      Knudsen, Martin::rp07147::600
# 4   Zakarwal, Schafiqa::rp07148::600
#
#                                                                                                                                                 dc.title[de]  \
# 0                       Zur Bedeutung der Gesellschaft für die Entwicklung von Essstörungen und deren Reflektion in mädchenspezifischen Präventionskonzepten
# 1                                                                                                       Ein modulares Sensor-Aktor-System für mobile Robotik
# 2  Gesundheitsauswirkungen des Setting-Ansatzes in Kitas: Der Einfluss eines Hamburger Modellprojektes auf die MitarbeiterInnenzufriedenheit und -gesundheit
# 3                                                             Realisierung eines mobilen Informationsdienstes durch eine Web 2.0 Applikation auf Smartphones
# 4  Afghanische Kultur ade- Interviewgestützte Befragung afghanischer Jugendlicher zu Einfluss und Wirkung audiovisueller Medien auf die kulturelle Identität
#
#   dc.title[en] tuhh.contributor.referee tuhh.gvk.ppn[]
# 0          NaN                      NaN      630150826
# 1          NaN                      NaN      662632974
# 2          NaN                      NaN      630155089
# 3          NaN                      NaN      663400872
# 4          NaN                      NaN      66340200X

# %%
#Die Spalte 'tuhh.gvk.ppn[]' soll umbenannt werden in 'PPN' 
dfReposit8Spalten.rename(columns={'tuhh.gvk.ppn[]': 'PPN'}, inplace=True)

# %%
dfReposit8Spalten.head()
# Out:
#      id      collection dc.contributor.advisor  \
# 0  5132  20.500.12738/6                    NaN
# 1  5360  20.500.12738/6                    NaN
# 2  5134  20.500.12738/6                    NaN
# 3  5376  20.500.12738/6                    NaN
# 4  5377  20.500.12738/6                    NaN
#
#              dc.contributor.author[]  \
# 0      Discher, Annika::rp06916::600
# 1  Eickhoff, Sebastian::rp07132::600
# 2      Richter, Sandra::rp06917::600
# 3      Knudsen, Martin::rp07147::600
# 4   Zakarwal, Schafiqa::rp07148::600
#
#                                                                                                                                                 dc.title[de]  \
# 0                       Zur Bedeutung der Gesellschaft für die Entwicklung von Essstörungen und deren Reflektion in mädchenspezifischen Präventionskonzepten
# 1                                                                                                       Ein modulares Sensor-Aktor-System für mobile Robotik
# 2  Gesundheitsauswirkungen des Setting-Ansatzes in Kitas: Der Einfluss eines Hamburger Modellprojektes auf die MitarbeiterInnenzufriedenheit und -gesundheit
# 3                                                             Realisierung eines mobilen Informationsdienstes durch eine Web 2.0 Applikation auf Smartphones
# 4  Afghanische Kultur ade- Interviewgestützte Befragung afghanischer Jugendlicher zu Einfluss und Wirkung audiovisueller Medien auf die kulturelle Identität
#
#   dc.title[en] tuhh.contributor.referee        PPN
# 0          NaN                      NaN  630150826
# 1          NaN                      NaN  662632974
# 2          NaN                      NaN  630155089
# 3          NaN                      NaN  663400872
# 4          NaN                      NaN  66340200X

# %%
dfReposit8Spalten.columns
# Out:
# Index(['id', 'collection', 'dc.contributor.advisor', 'dc.contributor.author[]',
#        'dc.title[de]', 'dc.title[en]', 'tuhh.contributor.referee', 'PPN'],
#       dtype='object')

# %%
#Inhalt der PPN-Spalte anzeigen lassen 
dfReposit8Spalten.PPN
# Out:
# 0       630150826
# 1       662632974
# 2       630155089
# 3       663400872
# 4       66340200X
#           ...
# 4877          NaN
# 4878          NaN
# 4879          NaN
# 4880          NaN
# 4881          NaN
# Name: PPN, Length: 4882, dtype: object

# %%
dfReposit8Spalten.shape
# Out:
# (4882, 8)

# %%
#Wie viele Datensätze enthalten keine PPN (sondern NaN)?
dfReposit8Spalten['PPN'].isna().sum()
# Out:
# 168

# %%
#Diese 168 Zeilen sollen gelöscht werden und das Ergebnis in eine neue Variable geschrieben werden
dfRepo = dfReposit8Spalten.dropna(subset=['PPN'])

# %%
dfRepo.shape
# Out:
# (4714, 8)

# %%
dfRepo.PPN
#Warum gibt es noch 4822 Datensätze statt nur nur 4714 ??
#Wie kann ich hier mehr als 10 Datensätze (alle) sehen - es könnte sein, dass es teilweise 2 PPNs gibt!?
# Out:
# 0        630150826
# 1        662632974
# 2        630155089
# 3        663400872
# 4        66340200X
#            ...
# 4818    1663351090
# 4819     558928919
# 4820     558923461
# 4821    1682114031
# 4822    1663248621
# Name: PPN, Length: 4714, dtype: object

# %%
#Mit print werden nur die korrekten 4714 Datensätze ausgegeben:
print(dfRepo)
# Out:
#         id      collection dc.contributor.advisor  \
# 0     5132  20.500.12738/6                    NaN
# 1     5360  20.500.12738/6                    NaN
# 2     5134  20.500.12738/6                    NaN
# 3     5376  20.500.12738/6                    NaN
# 4     5377  20.500.12738/6                    NaN
# ...    ...             ...                    ...
# 4818  8675  20.500.12738/6                    NaN
# 4819  8657  20.500.12738/6                    NaN
# 4820  8649  20.500.12738/6                    NaN
# 4821  9199  20.500.12738/6                    NaN
# 4822  8651  20.500.12738/6                    NaN
#
#                 dc.contributor.author[]  \
# 0         Discher, Annika::rp06916::600
# 1     Eickhoff, Sebastian::rp07132::600
# 2         Richter, Sandra::rp06917::600
# 3         Knudsen, Martin::rp07147::600
# 4      Zakarwal, Schafiqa::rp07148::600
# ...                                 ...
# 4818   Burgemeister, Erik::rp10164::600
# 4819        Noroozi, Reza::rp10148::600
# 4820         Keles, Fatih::rp10141::600
# 4821       Schubert, Lisa::rp10631::600
# 4822        Allers, Silke::rp10143::600
#
#                                                                                                                                                    dc.title[de]  \
# 0                          Zur Bedeutung der Gesellschaft für die Entwicklung von Essstörungen und deren Reflektion in mädchenspezifischen Präventionskonzepten
# 1                                                                                                          Ein modulares Sensor-Aktor-System für mobile Robotik
# 2     Gesundheitsauswirkungen des Setting-Ansatzes in Kitas: Der Einfluss eines Hamburger Modellprojektes auf die MitarbeiterInnenzufriedenheit und -gesundheit
# 3                                                                Realisierung eines mobilen Informationsdienstes durch eine Web 2.0 Applikation auf Smartphones
# 4     Afghanische Kultur ade- Interviewgestützte Befragung afghanischer Jugendlicher zu Einfluss und Wirkung audiovisueller Medien auf die kulturelle Identität
# ...                                                                                                                                                         ...
# 4818                                                                 Vergleich technischer Verbindungen zweier Subnetze zur Telemetrie patientenbezogener Daten
# 4819                                                                                                           Modellgetriebene Entwicklung aller SOA-Schichten
# 4820                                                                                          Ubiquitäre Annotationen und ortsbezogene Dienste im Zusammenspiel
# 4821                                                                                                                                                        NaN
# 4822                                                                                                                                                        NaN
#
#                                                                                                                                                                            dc.title[en]  \
# 0                                                                                                                                                                                   NaN
# 1                                                                                                                                                                                   NaN
# 2                                                                                                                                                                                   NaN
# 3                                                                                                                                                                                   NaN
# 4                                                                                                                                                                                   NaN
# ...                                                                                                                                                                                 ...
# 4818                                                                                                                                                                                NaN
# 4819                                                                                                                                                                                NaN
# 4820                                                                                                                                                                                NaN
# 4821  Analysis of the “Trans-European Transport Network” and the “Belt and Road Initiative” as Large-Scale Infrastructure Investment Policies for Infrastructure Development in EU-CEEC
# 4822                                               Establishment of RP-HPLC and SDS-PAGE analytics of an antiseptic peptide to investigate its elimination on a model waste water plant
#
#      tuhh.contributor.referee         PPN
# 0                         NaN   630150826
# 1                         NaN   662632974
# 2                         NaN   630155089
# 3                         NaN   663400872
# 4                         NaN   66340200X
# ...                       ...         ...
# 4818                      NaN  1663351090
# 4819                      NaN   558928919
# 4820                      NaN   558923461
# 4821                      NaN  1682114031
# 4822                      NaN  1663248621
#
# [4714 rows x 8 columns]

# %%
#Nächste Schritte: Weitere Bereinigungen (evtl. zwei PPNs in einer Zelle ; ...)

# %% [markdown]
# #Die zweite Datei (Abschlussarbeiten CBS) untersuchen

# %%
pd.set_option('max_columns', None)
dfCBS.head(10)
# Out:
#           PPN         EPN  Jahr ISBN  ISSN  ISMN  ZDBID  DOI  URN  \
# 0  1733687696  3760966098  2020  NaN   NaN   NaN    NaN  NaN  NaN
# 1  1733676007  3760764088  2020  NaN   NaN   NaN    NaN  NaN  NaN
# 2  1733673482  3760750737  2020  NaN   NaN   NaN    NaN  NaN  NaN
# 3  1733669124  3760732828  2020  NaN   NaN   NaN    NaN  NaN  NaN
# 4  1730486541  3749971722  2020  NaN   NaN   NaN    NaN  NaN  NaN
# 5  1729857345  3748910134  2020  NaN   NaN   NaN    NaN  NaN  NaN
# 6  1729822894  3748820674  2020  NaN   NaN   NaN    NaN  NaN  NaN
# 7  1729195466  3748003773  2020  NaN   NaN   NaN    NaN  NaN  NaN
# 8  1729181589  3747983693  2020  NaN   NaN   NaN    NaN  NaN  NaN
# 9  172915655X  3747905307  2020  NaN   NaN   NaN    NaN  NaN  NaN
#
#                                                       URL          Verfasser  \
# 0  http://edoc.sub.uni-hamburg.de/haw/volltexte/2020/5530    Kranert, Janina
# 1  http://edoc.sub.uni-hamburg.de/haw/volltexte/2020/5529  Liebetrau, Frauke
# 2  http://edoc.sub.uni-hamburg.de/haw/volltexte/2020/5528  Qalanawi, Morteza
# 3  http://edoc.sub.uni-hamburg.de/haw/volltexte/2020/5527  Schütt, Christine
# 4  http://edoc.sub.uni-hamburg.de/haw/volltexte/2020/5516    Sprenger, Armin
# 5  http://edoc.sub.uni-hamburg.de/haw/volltexte/2020/5507       Knipp, Liisa
# 6  http://edoc.sub.uni-hamburg.de/haw/volltexte/2020/5515    Hofmann, Robert
# 7  http://edoc.sub.uni-hamburg.de/haw/volltexte/2020/5514      Brand, Janine
# 8  http://edoc.sub.uni-hamburg.de/haw/volltexte/2020/5513       Georg, Marie
# 9  http://edoc.sub.uni-hamburg.de/haw/volltexte/2020/5512  Buchholz, Jeannie
#
#   weitereVerf.  \
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
#
#                                                                                   sonstPers  \
# 0  Dreier-Wolfgramm, Adina [AkademischeR BetreuerIn]; Dehning, Kathrin ; ID: gnd/1193095301
# 1     Richter, Miriam Tariba ; ID: gnd/135747341; Helfrich, Silke [AkademischeR BetreuerIn]
# 2       Stratmeyer, Peter *1955-* ; ID: gnd/123647495; Tamm, Lars [AkademischeR BetreuerIn]
# 3  Dreier-Wolfgramm, Adina [AkademischeR BetreuerIn]; Dehning, Kathrin ; ID: gnd/1193095301
# 4          Witt, Gesine [AkademischeR BetreuerIn]; Kröger, Denise [AkademischeR BetreuerIn]
# 5  Ullrich, Oliver [AkademischeR BetreuerIn]; Kutsche, Kerstin *1965-* ; ID: gnd/1027478948
# 6        Petersen-Ewert, Corinna ; ID: gnd/1148965343; Tamm, Lars [AkademischeR BetreuerIn]
# 7     Richter, Miriam Tariba ; ID: gnd/135747341; Behrens, Katrin [AkademischeR BetreuerIn]
# 8  Dreier-Wolfgramm, Adina [AkademischeR BetreuerIn]; Dehning, Kathrin ; ID: gnd/1193095301
# 9  Dreier-Wolfgramm, Adina [AkademischeR BetreuerIn]; Dehning, Kathrin ; ID: gnd/1193095301
#
#    Körperschaft3100  \
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
#
#                                                         Körperschaft3110  \
# 0  Hochschule für Angewandte Wissenschaften Hamburg ; ID: gnd/10029922-2
# 1  Hochschule für Angewandte Wissenschaften Hamburg ; ID: gnd/10029922-2
# 2  Hochschule für Angewandte Wissenschaften Hamburg ; ID: gnd/10029922-2
# 3  Hochschule für Angewandte Wissenschaften Hamburg ; ID: gnd/10029922-2
# 4  Hochschule für Angewandte Wissenschaften Hamburg ; ID: gnd/10029922-2
# 5  Hochschule für Angewandte Wissenschaften Hamburg ; ID: gnd/10029922-2
# 6  Hochschule für Angewandte Wissenschaften Hamburg ; ID: gnd/10029922-2
# 7  Hochschule für Angewandte Wissenschaften Hamburg ; ID: gnd/10029922-2
# 8  Hochschule für Angewandte Wissenschaften Hamburg ; ID: gnd/10029922-2
# 9  Hochschule für Angewandte Wissenschaften Hamburg ; ID: gnd/10029922-2
#
#                                                                                                                                                                        Titel  \
# 0                                                                                                                       Digitale Pflegesprechstunden in der Primärversorgung
# 1  Integrationsmaßnahmen zur Förderung der Fach- und Sprachkompetenz von Pflegefachkräften aus dem Ausland zur Umsetzung eines professionellen Pflegehandelns in Deutschland
# 2                                                                              Bindungsfördernde Arbeitsbedingungen innerhalb der pflegerischen Versorgung von Demenzkranken
# 3                                                                   Skills Lab Training in der akademischen Pflegeausbildung für die Versorgung von palliativen PatientInnen
# 4                                                                     Freisetzung von Schadstoffen in die Umwelt durch Desintegration von biologisch abbaubaren Kunststoffen
# 5                                                     Klonierung, heterologe Expression und subzelluläre Lokalisation von humanen Wildtyp- und vier FBXW11-Mutantenproteinen
# 6                                                                                                            Burnout bei Pflegefachkräften in der stationären Intensivpflege
# 7                                                                           Pflegerische Förderung der Bindungsentwicklung zwischen Frühgeborenen und Eltern nach der Geburt
# 8                                                                      Konzepte und Lerneffekte für interprofessionelles Simulationstraining in der pädiatrischen Versorgung
# 9                                                                                                                  Digitalisierung der Pflegedokumentation in Krankenhäusern
#
#                                                                                                                                                                                  Titel+Zusatz  \
# 0                                                                                                                       Digitale Pflegesprechstunden in der Primärversorgung : Bachelorarbeit
# 1  Integrationsmaßnahmen zur Förderung der Fach- und Sprachkompetenz von Pflegefachkräften aus dem Ausland zur Umsetzung eines professionellen Pflegehandelns in Deutschland : Bachelorarbeit
# 2                                                                              Bindungsfördernde Arbeitsbedingungen innerhalb der pflegerischen Versorgung von Demenzkranken : Bachelorarbeit
# 3                                        Skills Lab Training in der akademischen Pflegeausbildung für die Versorgung von palliativen PatientInnen : Konzepte und Lerneffekte : Bachelorarbeit
# 4                                                                                      Freisetzung von Schadstoffen in die Umwelt durch Desintegration von biologisch abbaubaren Kunststoffen
# 5                                                                      Klonierung, heterologe Expression und subzelluläre Lokalisation von humanen Wildtyp- und vier FBXW11-Mutantenproteinen
# 6                                                                                     Burnout bei Pflegefachkräften in der stationären Intensivpflege : Präventionsmaßnahmen : Bachelorarbeit
# 7                                                                           Pflegerische Förderung der Bindungsentwicklung zwischen Frühgeborenen und Eltern nach der Geburt : Bachelorarbeit
# 8                                                                      Konzepte und Lerneffekte für interprofessionelles Simulationstraining in der pädiatrischen Versorgung : Bachelorarbeit
# 9                                                                                                                  Digitalisierung der Pflegedokumentation in Krankenhäusern : Bachelorarbeit
#
#                                                                                                                                                             TitelOhneArtikel  \
# 0                                                                                                                       Digitale Pflegesprechstunden in der Primärversorgung
# 1  Integrationsmaßnahmen zur Förderung der Fach- und Sprachkompetenz von Pflegefachkräften aus dem Ausland zur Umsetzung eines professionellen Pflegehandelns in Deutschland
# 2                                                                              Bindungsfördernde Arbeitsbedingungen innerhalb der pflegerischen Versorgung von Demenzkranken
# 3                                                                   Skills Lab Training in der akademischen Pflegeausbildung für die Versorgung von palliativen PatientInnen
# 4                                                                     Freisetzung von Schadstoffen in die Umwelt durch Desintegration von biologisch abbaubaren Kunststoffen
# 5                                                     Klonierung, heterologe Expression und subzelluläre Lokalisation von humanen Wildtyp- und vier FBXW11-Mutantenproteinen
# 6                                                                                                            Burnout bei Pflegefachkräften in der stationären Intensivpflege
# 7                                                                           Pflegerische Förderung der Bindungsentwicklung zwischen Frühgeborenen und Eltern nach der Geburt
# 8                                                                      Konzepte und Lerneffekte für interprofessionelles Simulationstraining in der pädiatrischen Versorgung
# 9                                                                                                                  Digitalisierung der Pflegedokumentation in Krankenhäusern
#
#    GesamttitelMBW Ausgabe      Ort Verlag Ort+Verlag  \
# 0             NaN     NaN  Hamburg    NaN    Hamburg
# 1             NaN     NaN  Hamburg    NaN    Hamburg
# 2             NaN     NaN  Hamburg    NaN    Hamburg
# 3             NaN     NaN  Hamburg    NaN    Hamburg
# 4             NaN     NaN  Hamburg    NaN    Hamburg
# 5             NaN     NaN  Hamburg    NaN    Hamburg
# 6             NaN     NaN  Hamburg    NaN    Hamburg
# 7             NaN     NaN  Hamburg    NaN    Hamburg
# 8             NaN     NaN  Hamburg    NaN    Hamburg
# 9             NaN     NaN  Hamburg    NaN    Hamburg
#
#                                  Umfang Illustrationen  Schriftenreihe  DDC  \
# 0        1 Online-Ressource (67 Seiten)            NaN             NaN  NaN
# 1        1 Online-Ressource (64 Seiten)            NaN             NaN  NaN
# 2        1 Online-Ressource (83 Seiten)            NaN             NaN  NaN
# 3        1 Online-Ressource (43 Seiten)            NaN             NaN  NaN
# 4  1 Online-Ressource (XIII, 36 Seiten)            NaN             NaN  NaN
# 5    1 Online-Ressource (XI, 84 Seiten)            NaN             NaN  NaN
# 6       1 Online-Ressource ( 92 Seiten)            NaN             NaN  NaN
# 7        1 Online-Ressource (61 Seiten)            NaN             NaN  NaN
# 8        1 Online-Ressource (52 Seiten)            NaN             NaN  NaN
# 9        1 Online-Ressource (42 Seiten)            NaN             NaN  NaN
#
#    DNBSachgruppe  DNBDDC Basisklassifikation  LokaleNotation  \
# 0            NaN     NaN                 NaN             NaN
# 1            NaN     NaN                 NaN             NaN
# 2            NaN     NaN                 NaN             NaN
# 3            NaN     NaN                 NaN             NaN
# 4            NaN     NaN                 NaN             NaN
# 5            NaN     NaN                 NaN             NaN
# 6            NaN     NaN                 NaN             NaN
# 7            NaN     NaN                 NaN             NaN
# 8            NaN     NaN                 NaN             NaN
# 9            NaN     NaN                 NaN             NaN
#
#   LokalesSchlagwort Standort                            Signatur Ausleihcode  \
# 0               NaN   18/287  WS.Pf.BA (Elektronische Ressource)           o
# 1               NaN   18/287  WS.Pf.BA (Elektronische Ressource)           o
# 2               NaN   18/287  WS.Pf.BA (Elektronische Ressource)           o
# 3               NaN   18/287  WS.Pf.BA (Elektronische Ressource)           o
# 4               NaN   18/284  LS UT BA (Elektronische Ressource)           o
# 5               NaN   18/284  LS BT BA (Elektronische Ressource)           o
# 6               NaN   18/287  WS.Pf.BA (Elektronische Ressource)           o
# 7               NaN   18/287  WS.Pf.BA (Elektronische Ressource)           o
# 8               NaN   18/287  WS.Pf.BA (Elektronische Ressource)           o
# 9               NaN   18/287   WS.Pf.BA(Elektronische Ressource)           o
#
#                                         Standort+Signatur+AUI   Zugangsnr  \
# 0  SST: 18/287 SIG: WS.Pf.BA (Elektronische Ressource) AUI: o   saab20.28
# 1  SST: 18/287 SIG: WS.Pf.BA (Elektronische Ressource) AUI: o   saab20.29
# 2  SST: 18/287 SIG: WS.Pf.BA (Elektronische Ressource) AUI: o   saab20.30
# 3  SST: 18/287 SIG: WS.Pf.BA (Elektronische Ressource) AUI: o   saab20.31
# 4  SST: 18/284 SIG: LS UT BA (Elektronische Ressource) AUI: o  lsab20.104
# 5  SST: 18/284 SIG: LS BT BA (Elektronische Ressource) AUI: o  lsab20.103
# 6  SST: 18/287 SIG: WS.Pf.BA (Elektronische Ressource) AUI: o   saab20.27
# 7  SST: 18/287 SIG: WS.Pf.BA (Elektronische Ressource) AUI: o   saab20.26
# 8  SST: 18/287 SIG: WS.Pf.BA (Elektronische Ressource) AUI: o   saab20.25
# 9   SST: 18/287 SIG: WS.Pf.BA(Elektronische Ressource) AUI: o   saab20.24
#
#    Verbuchungsnr ExKommentar4801 ExKommentar4802  Bestandsangaben7120  \
# 0            NaN             NaN           nelsp                  NaN
# 1            NaN             NaN           nelsp                  NaN
# 2            NaN             NaN           nelsp                  NaN
# 3            NaN             NaN           nelsp                  NaN
# 4            NaN             NaN          neling                  NaN
# 5            NaN             NaN          nelnat                  NaN
# 6            NaN             NaN           nelsp                  NaN
# 7            NaN             NaN           nelsp                  NaN
# 8            NaN             NaN           nelsp                  NaN
# 9            NaN             NaN           nelsp                  NaN
#
#    Bestandsangaben7121 LokaleURL Notation6700  Schlagwort6800 Abrufzeichen8600
# 0                  NaN       NaN          NaN             NaN              NaN
# 1                  NaN       NaN          NaN             NaN              NaN
# 2                  NaN       NaN          NaN             NaN              NaN
# 3                  NaN       NaN          NaN             NaN              NaN
# 4                  NaN       NaN          NaN             NaN              NaN
# 5                  NaN       NaN          NaN             NaN              NaN
# 6                  NaN       NaN          NaN             NaN              NaN
# 7                  NaN       NaN          NaN             NaN              NaN
# 8                  NaN       NaN          NaN             NaN              NaN
# 9                  NaN       NaN          NaN             NaN              NaN

# %%
dfCBS.columns
# Out:
# Index(['PPN', 'EPN', 'Jahr', 'ISBN', 'ISSN', 'ISMN', 'ZDBID', 'DOI', 'URN',
#        'URL', 'Verfasser', 'weitereVerf.', 'sonstPers', 'Körperschaft3100',
#        'Körperschaft3110', 'Titel', 'Titel+Zusatz', 'TitelOhneArtikel',
#        'GesamttitelMBW', 'Ausgabe', 'Ort', 'Verlag', 'Ort+Verlag', 'Umfang',
#        'Illustrationen', 'Schriftenreihe', 'DDC', 'DNBSachgruppe', 'DNBDDC',
#        'Basisklassifikation', 'LokaleNotation', 'LokalesSchlagwort',
#        'Standort', 'Signatur', 'Ausleihcode', 'Standort+Signatur+AUI',
#        'Zugangsnr', 'Verbuchungsnr', 'ExKommentar4801', 'ExKommentar4802',
#        'Bestandsangaben7120', 'Bestandsangaben7121', 'LokaleURL',
#        'Notation6700', 'Schlagwort6800', 'Abrufzeichen8600'],
#       dtype='object')

# %%
#Die beiden Betreuer*innen befinden sich zusammen in der Spalte 'sonstPers'. Außerdem sollen PPN, Verfasser und
#Titel bleiben
#Datensätze ohne Inhalt im Feld "sonstPers" könnten gelöscht werden
#Die nicht benötigten Spalten mit "drop" löschen und Ergebnis in eine neue Variable schreiben:
dfCBS4Spalten = dfCBS.drop(['EPN', 'Jahr','ISBN', 'ISSN', 'ISMN', 'ZDBID', 'DOI', 'URN', 'URL', 'weitereVerf.', 'Körperschaft3100', 
            'Körperschaft3110', 'Titel+Zusatz', 'TitelOhneArtikel', 'GesamttitelMBW', 'Ausgabe', 'Ort', 
            'Verlag', 'Ort+Verlag', 'Umfang', 'Illustrationen', 'Schriftenreihe', 'DDC', 'DNBSachgruppe', 
            'DNBDDC', 'Basisklassifikation', 'LokaleNotation', 'LokalesSchlagwort', 'Standort', 'Signatur',
           'Ausleihcode', 'Standort+Signatur+AUI', 'Zugangsnr', 'Verbuchungsnr', 'ExKommentar4801', 
            'ExKommentar4802', 'Bestandsangaben7120', 'Bestandsangaben7121', 'LokaleURL', 'Notation6700', 
            'Schlagwort6800', 'Abrufzeichen8600'], axis=1)

# %%
dfCBS4Spalten.head(10)
# Out:
#           PPN          Verfasser  \
# 0  1733687696    Kranert, Janina
# 1  1733676007  Liebetrau, Frauke
# 2  1733673482  Qalanawi, Morteza
# 3  1733669124  Schütt, Christine
# 4  1730486541    Sprenger, Armin
# 5  1729857345       Knipp, Liisa
# 6  1729822894    Hofmann, Robert
# 7  1729195466      Brand, Janine
# 8  1729181589       Georg, Marie
# 9  172915655X  Buchholz, Jeannie
#
#                                                                                   sonstPers  \
# 0  Dreier-Wolfgramm, Adina [AkademischeR BetreuerIn]; Dehning, Kathrin ; ID: gnd/1193095301
# 1     Richter, Miriam Tariba ; ID: gnd/135747341; Helfrich, Silke [AkademischeR BetreuerIn]
# 2       Stratmeyer, Peter *1955-* ; ID: gnd/123647495; Tamm, Lars [AkademischeR BetreuerIn]
# 3  Dreier-Wolfgramm, Adina [AkademischeR BetreuerIn]; Dehning, Kathrin ; ID: gnd/1193095301
# 4          Witt, Gesine [AkademischeR BetreuerIn]; Kröger, Denise [AkademischeR BetreuerIn]
# 5  Ullrich, Oliver [AkademischeR BetreuerIn]; Kutsche, Kerstin *1965-* ; ID: gnd/1027478948
# 6        Petersen-Ewert, Corinna ; ID: gnd/1148965343; Tamm, Lars [AkademischeR BetreuerIn]
# 7     Richter, Miriam Tariba ; ID: gnd/135747341; Behrens, Katrin [AkademischeR BetreuerIn]
# 8  Dreier-Wolfgramm, Adina [AkademischeR BetreuerIn]; Dehning, Kathrin ; ID: gnd/1193095301
# 9  Dreier-Wolfgramm, Adina [AkademischeR BetreuerIn]; Dehning, Kathrin ; ID: gnd/1193095301
#
#                                                                                                                                                                        Titel
# 0                                                                                                                       Digitale Pflegesprechstunden in der Primärversorgung
# 1  Integrationsmaßnahmen zur Förderung der Fach- und Sprachkompetenz von Pflegefachkräften aus dem Ausland zur Umsetzung eines professionellen Pflegehandelns in Deutschland
# 2                                                                              Bindungsfördernde Arbeitsbedingungen innerhalb der pflegerischen Versorgung von Demenzkranken
# 3                                                                   Skills Lab Training in der akademischen Pflegeausbildung für die Versorgung von palliativen PatientInnen
# 4                                                                     Freisetzung von Schadstoffen in die Umwelt durch Desintegration von biologisch abbaubaren Kunststoffen
# 5                                                     Klonierung, heterologe Expression und subzelluläre Lokalisation von humanen Wildtyp- und vier FBXW11-Mutantenproteinen
# 6                                                                                                            Burnout bei Pflegefachkräften in der stationären Intensivpflege
# 7                                                                           Pflegerische Förderung der Bindungsentwicklung zwischen Frühgeborenen und Eltern nach der Geburt
# 8                                                                      Konzepte und Lerneffekte für interprofessionelles Simulationstraining in der pädiatrischen Versorgung
# 9                                                                                                                  Digitalisierung der Pflegedokumentation in Krankenhäusern

# %%
#Inhalt der sonstPers-Spalte anzeigen lassen 
#Mit ...max_colwith... ist die ganze Spaltenbreite sichtbar
pd.set_option('display.max_colwidth', None)
dfCBS4Spalten.sonstPers
# Out:
# 0       Dreier-Wolfgramm, Adina [AkademischeR BetreuerIn]; Dehning, Kathrin ; ID: gnd/1193095301
# 1          Richter, Miriam Tariba ; ID: gnd/135747341; Helfrich, Silke [AkademischeR BetreuerIn]
# 2            Stratmeyer, Peter *1955-* ; ID: gnd/123647495; Tamm, Lars [AkademischeR BetreuerIn]
# 3       Dreier-Wolfgramm, Adina [AkademischeR BetreuerIn]; Dehning, Kathrin ; ID: gnd/1193095301
# 4               Witt, Gesine [AkademischeR BetreuerIn]; Kröger, Denise [AkademischeR BetreuerIn]
#                                                   ...
# 4839                                            Weidner, Jens [Ref.]; Dargel, Wolfram [Ko.-Ref.]
# 4840                                               Weber, Petra [Ref.]; Busch, Susanne [Ko-Ref.]
# 4841                                           Schürgers, Georg [Ref.]; Zeichner, Dirk [Ko-Ref.]
# 4842                                             Eppel, Heidi [Ref.]; Strehmel, Petra [Ko.-Ref.]
# 4843                                                                                         NaN
# Name: sonstPers, Length: 4844, dtype: object

# %%
#Die beiden Betreuer*innen stehen in einem Feld und sind offenbar mit ; getrennt. Außerdem stehen dort auch
#GND-IDs - sollen diese erhalten bleiben? TEilweise sind auch Geburtsjahr genannt sowie die Benennung
#[AkademischeR BetreuerIn] ... 
#Vereinzelt gibt es auch 3 Betreuer*innen - die erste Person soll in die Spalte "dc.contributor.advisor, die
#weitere(n) Person(ein) in die Spalte tuhh.contributor.referee

# %%
#Wie viele Datensätze enthalten keinen Eintrag bei sonstPers (sondern NaN)?
dfCBS4Spalten['sonstPers'].isna().sum()
# Out:
# 2765

# %%
#Diese 2765 Zeilen sollen gelöscht werden und das Ergebnis in eine neue Variable geschrieben werden
dfCBS = dfCBS4Spalten.dropna(subset=['sonstPers'])

# %%
dfCBS.shape
# Out:
# (2079, 4)

# %%
dfCBS.tail()
#Warum werden hier doch wieder 4842 Zeilen ausgegeben, laut "shape" enthält die Datei doch nur noch 2079 ??
# Out:
#             PPN         Verfasser  \
# 4838  378156691  Leuker, Matthias
# 4839  379921146     Förster, Jens
# 4840  378154877     Dukar, Verena
# 4841  378151037     Heuck, Angela
# 4842  387133151       Pesch, Anja
#
#                                               sonstPers  \
# 4838   Hille, Jürgen [Ref.]; Schürgers, Georg [Ko-Ref.]
# 4839   Weidner, Jens [Ref.]; Dargel, Wolfram [Ko.-Ref.]
# 4840      Weber, Petra [Ref.]; Busch, Susanne [Ko-Ref.]
# 4841  Schürgers, Georg [Ref.]; Zeichner, Dirk [Ko-Ref.]
# 4842    Eppel, Heidi [Ref.]; Strehmel, Petra [Ko.-Ref.]
#
#                                                                                                              Titel
# 4838                            Soziale Arbeit zwischen konstruktivistischer Systemtheorie und politischen Bezügen
# 4839                    Glen Mills - zur Rezeption des konfrontativ-pädagogischen US-Behandlungsansatzes in Europa
# 4840  Konzeptentwicklung für eine biographische Gruppenarbeit mit dementen Bewohnern in der stationären Altenhilfe
# 4841                                                   Akutpsychiatrie und Beziehung - Skizze einer Unmöglichkeit?
# 4842                                                                                      Qualität aus Kindersicht

# %%
print(dfCBS)
# Out:
#              PPN          Verfasser  \
# 0     1733687696    Kranert, Janina
# 1     1733676007  Liebetrau, Frauke
# 2     1733673482  Qalanawi, Morteza
# 3     1733669124  Schütt, Christine
# 4     1730486541    Sprenger, Armin
# ...          ...                ...
# 4838   378156691   Leuker, Matthias
# 4839   379921146      Förster, Jens
# 4840   378154877      Dukar, Verena
# 4841   378151037      Heuck, Angela
# 4842   387133151        Pesch, Anja
#
#                                                                                      sonstPers  \
# 0     Dreier-Wolfgramm, Adina [AkademischeR BetreuerIn]; Dehning, Kathrin ; ID: gnd/1193095301
# 1        Richter, Miriam Tariba ; ID: gnd/135747341; Helfrich, Silke [AkademischeR BetreuerIn]
# 2          Stratmeyer, Peter *1955-* ; ID: gnd/123647495; Tamm, Lars [AkademischeR BetreuerIn]
# 3     Dreier-Wolfgramm, Adina [AkademischeR BetreuerIn]; Dehning, Kathrin ; ID: gnd/1193095301
# 4             Witt, Gesine [AkademischeR BetreuerIn]; Kröger, Denise [AkademischeR BetreuerIn]
# ...                                                                                        ...
# 4838                                          Hille, Jürgen [Ref.]; Schürgers, Georg [Ko-Ref.]
# 4839                                          Weidner, Jens [Ref.]; Dargel, Wolfram [Ko.-Ref.]
# 4840                                             Weber, Petra [Ref.]; Busch, Susanne [Ko-Ref.]
# 4841                                         Schürgers, Georg [Ref.]; Zeichner, Dirk [Ko-Ref.]
# 4842                                           Eppel, Heidi [Ref.]; Strehmel, Petra [Ko.-Ref.]
#
#                                                                                                                                                                           Titel
# 0                                                                                                                          Digitale Pflegesprechstunden in der Primärversorgung
# 1     Integrationsmaßnahmen zur Förderung der Fach- und Sprachkompetenz von Pflegefachkräften aus dem Ausland zur Umsetzung eines professionellen Pflegehandelns in Deutschland
# 2                                                                                 Bindungsfördernde Arbeitsbedingungen innerhalb der pflegerischen Versorgung von Demenzkranken
# 3                                                                      Skills Lab Training in der akademischen Pflegeausbildung für die Versorgung von palliativen PatientInnen
# 4                                                                        Freisetzung von Schadstoffen in die Umwelt durch Desintegration von biologisch abbaubaren Kunststoffen
# ...                                                                                                                                                                         ...
# 4838                                                                                         Soziale Arbeit zwischen konstruktivistischer Systemtheorie und politischen Bezügen
# 4839                                                                                 Glen Mills - zur Rezeption des konfrontativ-pädagogischen US-Behandlungsansatzes in Europa
# 4840                                                               Konzeptentwicklung für eine biographische Gruppenarbeit mit dementen Bewohnern in der stationären Altenhilfe
# 4841                                                                                                                Akutpsychiatrie und Beziehung - Skizze einer Unmöglichkeit?
# 4842                                                                                                                                                   Qualität aus Kindersicht
#
# [2079 rows x 4 columns]

# %%
#Nächste SChritte:
#Prüfen, warum nur so wenige Datensätze in der CBS-Datei eine PPN entalten! Liegt ein Fehler bei der Abfrage vor?
#Der Inhalt der Spalte "sonstPers" muss gesplittet und bereinigt werden
#Wenn das erfolgt ist, können die beiden Dateien gemerget werden

# %%
#Der Inhalt der Spalte "sonstPers" muss gesplittet werden - die erste Person soll in die Spalte 
#dc.contributors geschrieben werden, alle weiterenn Personen in die Spalte #tuhh.contributors.referee  
#Anhand welcher Separatoren splitten? -> Semikolon als Separator, wenn vor diesem kein Blank steht
#Also könnte ich zuerat alle Semikolons ausschneiden, vor und nach denen ein Blank steht. Oder alternativ
#die wichtigen Semikolons, also die ohne Blank davor, mit einem anderen, eindeutigen Zeichen ersetzen,
#welches dann der Separator wäre? 
dfCBS.sonstPers
# Out:
# 0       Dreier-Wolfgramm, Adina [AkademischeR BetreuerIn]; Dehning, Kathrin ; ID: gnd/1193095301
# 1          Richter, Miriam Tariba ; ID: gnd/135747341; Helfrich, Silke [AkademischeR BetreuerIn]
# 2            Stratmeyer, Peter *1955-* ; ID: gnd/123647495; Tamm, Lars [AkademischeR BetreuerIn]
# 3       Dreier-Wolfgramm, Adina [AkademischeR BetreuerIn]; Dehning, Kathrin ; ID: gnd/1193095301
# 4               Witt, Gesine [AkademischeR BetreuerIn]; Kröger, Denise [AkademischeR BetreuerIn]
#                                                   ...
# 4838                                            Hille, Jürgen [Ref.]; Schürgers, Georg [Ko-Ref.]
# 4839                                            Weidner, Jens [Ref.]; Dargel, Wolfram [Ko.-Ref.]
# 4840                                               Weber, Petra [Ref.]; Busch, Susanne [Ko-Ref.]
# 4841                                           Schürgers, Georg [Ref.]; Zeichner, Dirk [Ko-Ref.]
# 4842                                             Eppel, Heidi [Ref.]; Strehmel, Petra [Ko.-Ref.]
# Name: sonstPers, Length: 2079, dtype: object

# %%
#Versuch, alle Semikolons ohne Blank davor mit einem ? zu ersetzen:
dfCBS['sonstPers'] = dfCBS.replace('; ', '  ?  ', regex=True)
#Was bedeutet die Fehlermeldung?
# Out:
# <ipython-input-113-ebeb23b13dd0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfCBS['sonstPers'] = dfCBS.replace('; ', '  ?  ', regex=True)

# %%
#Erster Merge-Versuch:
Merge1 = dfRepo.merge(dfCBS, on='PPN', how='inner')

# %%
Merge1.shape
#Mergen scheint prinzipiell zu klappen, aber warum nur für 182 Datensätze??
# Out:
# (182, 11)

# %%
Merge1.head()
# Out:
#      id      collection dc.contributor.advisor  \
# 0  5136  20.500.12738/6                    NaN
# 1  7707  20.500.12738/6                    NaN
# 2  5147  20.500.12738/6                    NaN
# 3  5410  20.500.12738/6                    NaN
# 4  8687  20.500.12738/6                    NaN
#
#                 dc.contributor.author[]  \
# 0         Sundas, Claudia::rp06919::600
# 1        Behrens, Hendrik::rp09296::600
# 2           Koch, Lennart::rp06929::600
# 3  Wischnewski, Christine::rp07181::600
# 4        Herzberg, Hannes::rp10174::600
#
#                                                                                                                       dc.title[de]  \
# 0                      Modellprojekt „filmreif“ : Konzeption eines interkulturellen medienpädagogischen Videoprojektes mit Kindern
# 1                           Integration einer RFID-basierten Vorflugkontrolle für Notfallausrüstung in ein Kabinenmanagementsystem
# 2                                             Aufwandsminimierte Schätzung von Harmonischen zur Zustandsbestimmungvon ABS-Sensoren
# 3                                                                                                   Autoimmunthyreoditis und Selen
# 4  Die Bedeutung von Familie für unbegleitete minderjährige Flüchtlinge – Ein Konzept für eine pädagogische Unterstützungsmaßnahme
#
#   dc.title[en] tuhh.contributor.referee         PPN               Verfasser  \
# 0          NaN                      NaN   51844483X         Sundas, Claudia
# 1          NaN                      NaN   87332272X        Behrens, Hendrik
# 2          NaN                      NaN   63311989X           Koch, Lennart
# 3          NaN                      NaN   52370643X  Wischnewski, Christine
# 4          NaN                      NaN  166356213X        Herzberg, Hannes
#
#     sonstPers  \
# 0   51844483X
# 1   87332272X
# 2   63311989X
# 3   52370643X
# 4  166356213X
#
#                                                                                                         Titel
# 0  Modellprojekt 'filmreif': Konzeption eines interkulturellen medienpädagogischen Videoprojektes mit Kindern
# 1      Integration einer RFID-basierten Vorflugkontrolle für Notfallausrüstung in ein Kabinenmanagementsystem
# 2                       Aufwandsminimierte Schätzung der Harmonischen zur Zustandsbestimmung von ABS-Sensoren
# 3                                                                              Autoimmunthyreoditis und Selen
# 4                                        Die Bedeutung von Familie für unbegleitete minderjährige Flüchtlinge

# %%
#Versuch mit left join zu mergen:
dfRepo.merge(dfCBS, on='PPN', how='left', left_index=True, right_index=True)
#Das gleiche Ergebnis erhalte ich mit: "pd.merge(dfRepo, dfCBS, on='PPN', how='left').head(10)"
# Out:
#         id      collection dc.contributor.advisor  \
# 0     5132  20.500.12738/6                    NaN
# 1     5360  20.500.12738/6                    NaN
# 2     5134  20.500.12738/6                    NaN
# 3     5376  20.500.12738/6                    NaN
# 4     5377  20.500.12738/6                    NaN
# ...    ...             ...                    ...
# 4818  8675  20.500.12738/6                    NaN
# 4819  8657  20.500.12738/6                    NaN
# 4820  8649  20.500.12738/6                    NaN
# 4821  9199  20.500.12738/6                    NaN
# 4822  8651  20.500.12738/6                    NaN
#
#                 dc.contributor.author[]  \
# 0         Discher, Annika::rp06916::600
# 1     Eickhoff, Sebastian::rp07132::600
# 2         Richter, Sandra::rp06917::600
# 3         Knudsen, Martin::rp07147::600
# 4      Zakarwal, Schafiqa::rp07148::600
# ...                                 ...
# 4818   Burgemeister, Erik::rp10164::600
# 4819        Noroozi, Reza::rp10148::600
# 4820         Keles, Fatih::rp10141::600
# 4821       Schubert, Lisa::rp10631::600
# 4822        Allers, Silke::rp10143::600
#
#                                                                                                                                                    dc.title[de]  \
# 0                          Zur Bedeutung der Gesellschaft für die Entwicklung von Essstörungen und deren Reflektion in mädchenspezifischen Präventionskonzepten
# 1                                                                                                          Ein modulares Sensor-Aktor-System für mobile Robotik
# 2     Gesundheitsauswirkungen des Setting-Ansatzes in Kitas: Der Einfluss eines Hamburger Modellprojektes auf die MitarbeiterInnenzufriedenheit und -gesundheit
# 3                                                                Realisierung eines mobilen Informationsdienstes durch eine Web 2.0 Applikation auf Smartphones
# 4     Afghanische Kultur ade- Interviewgestützte Befragung afghanischer Jugendlicher zu Einfluss und Wirkung audiovisueller Medien auf die kulturelle Identität
# ...                                                                                                                                                         ...
# 4818                                                                 Vergleich technischer Verbindungen zweier Subnetze zur Telemetrie patientenbezogener Daten
# 4819                                                                                                           Modellgetriebene Entwicklung aller SOA-Schichten
# 4820                                                                                          Ubiquitäre Annotationen und ortsbezogene Dienste im Zusammenspiel
# 4821                                                                                                                                                        NaN
# 4822                                                                                                                                                        NaN
#
#                                                                                                                                                                            dc.title[en]  \
# 0                                                                                                                                                                                   NaN
# 1                                                                                                                                                                                   NaN
# 2                                                                                                                                                                                   NaN
# 3                                                                                                                                                                                   NaN
# 4                                                                                                                                                                                   NaN
# ...                                                                                                                                                                                 ...
# 4818                                                                                                                                                                                NaN
# 4819                                                                                                                                                                                NaN
# 4820                                                                                                                                                                                NaN
# 4821  Analysis of the “Trans-European Transport Network” and the “Belt and Road Initiative” as Large-Scale Infrastructure Investment Policies for Infrastructure Development in EU-CEEC
# 4822                                               Establishment of RP-HPLC and SDS-PAGE analytics of an antiseptic peptide to investigate its elimination on a model waste water plant
#
#      tuhh.contributor.referee         PPN             Verfasser   sonstPers  \
# 0                         NaN   630150826       Kranert, Janina  1733687696
# 1                         NaN   662632974     Liebetrau, Frauke  1733676007
# 2                         NaN   630155089     Qalanawi, Morteza  1733673482
# 3                         NaN   663400872     Schütt, Christine  1733669124
# 4                         NaN   66340200X       Sprenger, Armin  1730486541
# ...                       ...         ...                   ...         ...
# 4818                      NaN  1663351090      Mahlmann, Thomas   481700927
# 4819                      NaN   558928919    Kasischke, Pia-Lin   478295464
# 4820                      NaN   558923461  Hohensee, Christiane   478290330
# 4821                      NaN  1682114031          Jüdt, Thomas   477402321
# 4822                      NaN  1663248621      Brieger, Manuela   477398553
#
#                                                                                                                                                                           Titel
# 0                                                                                                                          Digitale Pflegesprechstunden in der Primärversorgung
# 1     Integrationsmaßnahmen zur Förderung der Fach- und Sprachkompetenz von Pflegefachkräften aus dem Ausland zur Umsetzung eines professionellen Pflegehandelns in Deutschland
# 2                                                                                 Bindungsfördernde Arbeitsbedingungen innerhalb der pflegerischen Versorgung von Demenzkranken
# 3                                                                      Skills Lab Training in der akademischen Pflegeausbildung für die Versorgung von palliativen PatientInnen
# 4                                                                        Freisetzung von Schadstoffen in die Umwelt durch Desintegration von biologisch abbaubaren Kunststoffen
# ...                                                                                                                                                                         ...
# 4818                                                                                                                    Pflegeberatung von Patienten mit tumorbedingter Fatigue
# 4819                                                                              Humanistische Altenpflege! - Anforderungen für die Umsetzung der humanistischen Pflegetheorie
# 4820                                                                              Entwicklung eines Anamnesebogens zur Erfassung musikbiographischer Daten von Demenzerkrankten
# 4821                                                                                        Verfahrenstechnische Untersuchung einer Anlage zur dezentralen Abwasseraufbereitung
# 4822                                                        Die wissenschaftliche Haltbarkeit der Theorie der 'Bedarfsorientierten Ernährung' und ihre Bedeutung für die Praxis
#
# [4714 rows x 11 columns]

# %%
#Jetzt 4714 Zeilen - aber das Mergen hat nicht geklappt. Bsp. erster Datensatz: Die PPN stammt aus der
#Reposit-Datei. Die Angaben in den letzten 3 Spalten beziehen sich aber auf eine andere PPN (1733687696),
#die aber hier nicht angezeigt wird. Ursache??

# %%
#Versuch, whitespaces aus der Spalte "PPN" im dfCBS zu entfernen, die evtl. die Ursache dafür sind, dass das
#Mergen nicht klappt. Funktioniert nicht, warum? 
dfCBS['PPN'].str.strip()
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 4838    NaN
# 4839    NaN
# 4840    NaN
# 4841    NaN
# 4842    NaN
# Name: PPN, Length: 2079, dtype: object

# %%
#Neuer Versuch mit str.replace - ergibt u.g. Fehlermeldung!??
dfCBS['PPN'] = dfCBS['PPN'].str.replace(" ", "")
# Out:
# <ipython-input-131-b1974a215a28>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfCBS['PPN'] = dfCBS['PPN'].str.replace(" ", "")
