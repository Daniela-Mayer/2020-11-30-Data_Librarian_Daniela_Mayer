# %% [markdown]
# #Es liegt eine Excel-Datei "AbschlussarbeitenReposit" (Export aus dem Repositorium der HAW Hamburg) vor, bei der die Namen der (Ko-)Referent:innen fehlen. Diese sollen dort ergänzt werden. Dafür wurde eine weitere Excel-Datei  erzeugt ("CBS_Export_3010_3050", Datenabzug aus dem CBS-Katalogisierungssystem). Die beiden Dateien sollen bearbeitet und anhand des gemeinsamen Identifikators PPN zusammengeführt werden.

# %% [markdown]
# Die CBS-Datei enthält alle Namen der Betreuer*innen, aber in zwei versch. Spalten (sonstPers und sonstPers2). Diese zwei Spalten sollen zunächst zusammengeführt werden.

# %%
import pandas as pd

# %% [markdown]
# # 1. Die CBS-Datei einlesen, untersuchen und bearbeiten

# %%
dfCBS = pd.read_excel("../data/CBS_Export_3010_3050.xlsx")

# %%
#Alle vorhandenen Spalten werden mit ...max_columns, None... angezeigt 
pd.set_option('max_columns', None)
dfCBS.head()
# Out:
#           PPN         EPN          Verfasser  \
# 0  1733687696  3760966098    Kranert, Janina
# 1  1733676007  3760764088  Liebetrau, Frauke
# 2  1733673482  3760750737  Qalanawi, Morteza
# 3  1733669124  3760732828  Schütt, Christine
# 4  1730486541  3749971722    Sprenger, Armin
#
#                                            sonstPers sonstPers2  \
# 0  Dreier-Wolfgramm, Adina [AkademischeR Betreuer...        NaN
# 1  Richter, Miriam Tariba ; ID: gnd/135747341; He...        NaN
# 2  Stratmeyer, Peter *1955-* ; ID: gnd/123647495;...        NaN
# 3  Dreier-Wolfgramm, Adina [AkademischeR Betreuer...        NaN
# 4  Witt, Gesine [AkademischeR BetreuerIn]; Kröger...        NaN
#
#                                                Titel
# 0  Digitale Pflegesprechstunden in der Primärvers...
# 1  Integrationsmaßnahmen zur Förderung der Fach- ...
# 2  Bindungsfördernde Arbeitsbedingungen innerhalb...
# 3  Skills Lab Training in der akademischen Pflege...
# 4  Freisetzung von Schadstoffen in die Umwelt dur...

# %%
#Die nicht benötigte Spalte "EPN" mit "drop" löschen:
dfCBS = dfCBS.drop(['EPN'], axis=1)

# %%
pd.set_option('max_columns', None)
dfCBS.head()
# Out:
#           PPN          Verfasser  \
# 0  1733687696    Kranert, Janina
# 1  1733676007  Liebetrau, Frauke
# 2  1733673482  Qalanawi, Morteza
# 3  1733669124  Schütt, Christine
# 4  1730486541    Sprenger, Armin
#
#                                            sonstPers sonstPers2  \
# 0  Dreier-Wolfgramm, Adina [AkademischeR Betreuer...        NaN
# 1  Richter, Miriam Tariba ; ID: gnd/135747341; He...        NaN
# 2  Stratmeyer, Peter *1955-* ; ID: gnd/123647495;...        NaN
# 3  Dreier-Wolfgramm, Adina [AkademischeR Betreuer...        NaN
# 4  Witt, Gesine [AkademischeR BetreuerIn]; Kröger...        NaN
#
#                                                Titel
# 0  Digitale Pflegesprechstunden in der Primärvers...
# 1  Integrationsmaßnahmen zur Förderung der Fach- ...
# 2  Bindungsfördernde Arbeitsbedingungen innerhalb...
# 3  Skills Lab Training in der akademischen Pflege...
# 4  Freisetzung von Schadstoffen in die Umwelt dur...

# %%
#Wie groß ist die Datei?
dfCBS.shape
# Out:
# (4826, 5)

# %%
#Wie viele Datensätze sind bei "sonstPers" leer? 
dfCBS['sonstPers'].isna().sum()
# Out:
# 2753

# %%
#Wie viele Datensätze sind bei "sonstPers2" leer? 
dfCBS['sonstPers2'].isna().sum()
# Out:
# 2078

# %%
#Der Inhalt der Spalte "sonstPers2" soll in die Spalte "sonstPers" geschrieben werden, falls "sonstPers2" nicht NaN ist. 
#Mithilfe der Funktion update.
dfCBS['sonstPers'].update(dfCBS['sonstPers2'])

# %%
#Nun enthalten alle 4826 Datensätze die Personennamen in der Spalte "sonstPers" - alle sichtbar mit
#dfCBS['sonstPers']
pd.set_option("max_rows", None)
dfCBS['sonstPers'].head()
# Out:
# 0    Dreier-Wolfgramm, Adina [AkademischeR Betreuer...
# 1    Richter, Miriam Tariba ; ID: gnd/135747341; He...
# 2    Stratmeyer, Peter *1955-* ; ID: gnd/123647495;...
# 3    Dreier-Wolfgramm, Adina [AkademischeR Betreuer...
# 4    Witt, Gesine [AkademischeR BetreuerIn]; Kröger...
# Name: sonstPers, dtype: object

# %%
#Die Spalte "sonstPers2" kann gelöscht werden
dfCBS = dfCBS.drop(['sonstPers2'], axis=1)

# %%
dfCBS.head()
# Out:
#           PPN          Verfasser  \
# 0  1733687696    Kranert, Janina
# 1  1733676007  Liebetrau, Frauke
# 2  1733673482  Qalanawi, Morteza
# 3  1733669124  Schütt, Christine
# 4  1730486541    Sprenger, Armin
#
#                                            sonstPers  \
# 0  Dreier-Wolfgramm, Adina [AkademischeR Betreuer...
# 1  Richter, Miriam Tariba ; ID: gnd/135747341; He...
# 2  Stratmeyer, Peter *1955-* ; ID: gnd/123647495;...
# 3  Dreier-Wolfgramm, Adina [AkademischeR Betreuer...
# 4  Witt, Gesine [AkademischeR BetreuerIn]; Kröger...
#
#                                                Titel
# 0  Digitale Pflegesprechstunden in der Primärvers...
# 1  Integrationsmaßnahmen zur Förderung der Fach- ...
# 2  Bindungsfördernde Arbeitsbedingungen innerhalb...
# 3  Skills Lab Training in der akademischen Pflege...
# 4  Freisetzung von Schadstoffen in die Umwelt dur...

# %%
#Datei als Excel speichern, um sie prüfen zu können. 
dfCBS.to_excel("../data/CBSneu.xlsx")

# %%
#Die neue Excel-Datei muss wieder eingelesen werden, damit die folgeden Operationen durchgeführt werden können. 
#Alternativ wäre ein Weiterarbeiten mit Kopien (Funktion copy()) möglich. 
dfCBSneu = pd.read_excel("../data/CBSneu.xlsx")

# %%
#Eventuelle Integer-Werte in Strings umwandeln, damit weiteren Operationen funktionieren
dfCBSneu['sonstPers'] = dfCBSneu['sonstPers'].astype("str")

# %%
#In der Spalte "sonstPers" stehen alle Personennamen (sowie diverse Zahlen und Sonderzeichen). Die Namen sollen aber
#in versch. Spalten geschrieben werden: Der/die erste Ref. in einer Spalte namens "Ref", alle Ko-Ref. in einer 
#zweiten Spalte "RefID_plus_KoRef". #D.h. alles, was bei "sonstPers" rechts des ersten Semikolons steht, soll 
#in eine neue Spalte namens "RefID_plus_KoRef": 
dfCBSneu['RefID_plus_KoRef'] = dfCBSneu['sonstPers'].apply(lambda cell: ";".join(cell.split(";")[1:]))

# %%
#Alles, was in der Spalte "sonstPers" links des ersten Semikolons steht, in eine neue Spalte "Ref" schreiben:
dfCBSneu['Ref'] = dfCBSneu['sonstPers'].apply(lambda cell: ";".join(cell.split(";")[:1]))

# %%
dfCBSneu.head(5)
# Out:
#    Unnamed: 0         PPN          Verfasser  \
# 0           0  1733687696    Kranert, Janina
# 1           1  1733676007  Liebetrau, Frauke
# 2           2  1733673482  Qalanawi, Morteza
# 3           3  1733669124  Schütt, Christine
# 4           4  1730486541    Sprenger, Armin
#
#                                            sonstPers  \
# 0  Dreier-Wolfgramm, Adina [AkademischeR Betreuer...
# 1  Richter, Miriam Tariba ; ID: gnd/135747341; He...
# 2  Stratmeyer, Peter *1955-* ; ID: gnd/123647495;...
# 3  Dreier-Wolfgramm, Adina [AkademischeR Betreuer...
# 4  Witt, Gesine [AkademischeR BetreuerIn]; Kröger...
#
#                                                Titel  \
# 0  Digitale Pflegesprechstunden in der Primärvers...
# 1  Integrationsmaßnahmen zur Förderung der Fach- ...
# 2  Bindungsfördernde Arbeitsbedingungen innerhalb...
# 3  Skills Lab Training in der akademischen Pflege...
# 4  Freisetzung von Schadstoffen in die Umwelt dur...
#
#                                     RefID_plus_KoRef  \
# 0              Dehning, Kathrin ; ID: gnd/1193095301
# 1   ID: gnd/135747341; Helfrich, Silke [Akademisc...
# 2   ID: gnd/123647495; Tamm, Lars [AkademischeR B...
# 3              Dehning, Kathrin ; ID: gnd/1193095301
# 4           Kröger, Denise [AkademischeR BetreuerIn]
#
#                                                  Ref
# 0  Dreier-Wolfgramm, Adina [AkademischeR BetreuerIn]
# 1                            Richter, Miriam Tariba
# 2                         Stratmeyer, Peter *1955-*
# 3  Dreier-Wolfgramm, Adina [AkademischeR BetreuerIn]
# 4             Witt, Gesine [AkademischeR BetreuerIn]

# %%
dfCBSneu.shape
# Out:
# (4826, 7)

# %%
#Als neue Excel-Tabelle speichern, um die Daten prüfen zu können:
dfCBSneu.to_excel("../data/CBSneuRef.xlsx")
#Ergebnis: Alle Spalten mit Personennamen sind korrekt befüllt.

# %%
#Diese neue Excel-Datei einlesen
dfCBSneu = pd.read_excel("../data/CBSneuRef.xlsx")

# %%
dfCBSneu.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0.1         PPN          Verfasser  \
# 0           0             0  1733687696    Kranert, Janina
# 1           1             1  1733676007  Liebetrau, Frauke
# 2           2             2  1733673482  Qalanawi, Morteza
# 3           3             3  1733669124  Schütt, Christine
# 4           4             4  1730486541    Sprenger, Armin
#
#                                            sonstPers  \
# 0  Dreier-Wolfgramm, Adina [AkademischeR Betreuer...
# 1  Richter, Miriam Tariba ; ID: gnd/135747341; He...
# 2  Stratmeyer, Peter *1955-* ; ID: gnd/123647495;...
# 3  Dreier-Wolfgramm, Adina [AkademischeR Betreuer...
# 4  Witt, Gesine [AkademischeR BetreuerIn]; Kröger...
#
#                                                Titel  \
# 0  Digitale Pflegesprechstunden in der Primärvers...
# 1  Integrationsmaßnahmen zur Förderung der Fach- ...
# 2  Bindungsfördernde Arbeitsbedingungen innerhalb...
# 3  Skills Lab Training in der akademischen Pflege...
# 4  Freisetzung von Schadstoffen in die Umwelt dur...
#
#                                     RefID_plus_KoRef  \
# 0              Dehning, Kathrin ; ID: gnd/1193095301
# 1   ID: gnd/135747341; Helfrich, Silke [Akademisc...
# 2   ID: gnd/123647495; Tamm, Lars [AkademischeR B...
# 3              Dehning, Kathrin ; ID: gnd/1193095301
# 4           Kröger, Denise [AkademischeR BetreuerIn]
#
#                                                  Ref
# 0  Dreier-Wolfgramm, Adina [AkademischeR BetreuerIn]
# 1                            Richter, Miriam Tariba
# 2                         Stratmeyer, Peter *1955-*
# 3  Dreier-Wolfgramm, Adina [AkademischeR BetreuerIn]
# 4             Witt, Gesine [AkademischeR BetreuerIn]

# %%
#Die beiden neu entstandenen Index-Spalten löschen
dfCBSneu = dfCBSneu.drop(['Unnamed: 0'], axis=1)

# %%
dfCBSneu = dfCBSneu.drop(['Unnamed: 0.1'], axis=1)

# %%
dfCBSneu.head()
# Out:
#           PPN          Verfasser  \
# 0  1733687696    Kranert, Janina
# 1  1733676007  Liebetrau, Frauke
# 2  1733673482  Qalanawi, Morteza
# 3  1733669124  Schütt, Christine
# 4  1730486541    Sprenger, Armin
#
#                                            sonstPers  \
# 0  Dreier-Wolfgramm, Adina [AkademischeR Betreuer...
# 1  Richter, Miriam Tariba ; ID: gnd/135747341; He...
# 2  Stratmeyer, Peter *1955-* ; ID: gnd/123647495;...
# 3  Dreier-Wolfgramm, Adina [AkademischeR Betreuer...
# 4  Witt, Gesine [AkademischeR BetreuerIn]; Kröger...
#
#                                                Titel  \
# 0  Digitale Pflegesprechstunden in der Primärvers...
# 1  Integrationsmaßnahmen zur Förderung der Fach- ...
# 2  Bindungsfördernde Arbeitsbedingungen innerhalb...
# 3  Skills Lab Training in der akademischen Pflege...
# 4  Freisetzung von Schadstoffen in die Umwelt dur...
#
#                                     RefID_plus_KoRef  \
# 0              Dehning, Kathrin ; ID: gnd/1193095301
# 1   ID: gnd/135747341; Helfrich, Silke [Akademisc...
# 2   ID: gnd/123647495; Tamm, Lars [AkademischeR B...
# 3              Dehning, Kathrin ; ID: gnd/1193095301
# 4           Kröger, Denise [AkademischeR BetreuerIn]
#
#                                                  Ref
# 0  Dreier-Wolfgramm, Adina [AkademischeR BetreuerIn]
# 1                            Richter, Miriam Tariba
# 2                         Stratmeyer, Peter *1955-*
# 3  Dreier-Wolfgramm, Adina [AkademischeR BetreuerIn]
# 4             Witt, Gesine [AkademischeR BetreuerIn]

# %%
#In den Spalten "Ref" und RefID_plus_KoRef" soll alles entfernt werden, was nicht "Nachname, Vorname" ist. 
#Also die Bezeichnungen in eckigen Klammern, alle Zahlen und Sonderzeichen (außer dem Komma zwischen Nachname und Vorname). 
#Dazu eine Kopie der Spalte "Ref" anfertigen und mit str.extract entfernen, was in der Klammer mithilfe Regulärer Ausdrücke (RegEx) definiert wird 
#
#dfCBSneu['RefKopie'] = dfCBSneu['Ref']
#dfCBSneu['RefKopie'] = dfCBSneu['RefKopie'].str.extract('([\w \-\.]+,\s*[\w \-\.]+)')
#
#Ergänzung: Es sollen auch die Leerzeichen vor den Nachnamen entfernt werden, die man nur in der CSV-Version der Merge2-Datei sieht: 
#
#dfCBSneu['RefKopie'] = dfCBSneu['Ref']
#dfCBSneu['RefKopie'] = dfCBSneu['RefKopie'].str.extract('(\w[\w \-\.]*,\s*\w[\w \-\.]*[\w\.])')
#
#Weitere Verbesserung (Ergänzung um $), um Namenszusätze "van" bzw."von" mit auszugeben.  
#Korrektur: Der Punkt benötigt grunds. kein Escapen, der Bindestrich nicht, wenn er am Anfang oder Ende der [ ] steht:
dfCBSneu['RefKopie'] = dfCBSneu['Ref']
dfCBSneu['RefKopie'] = dfCBSneu['RefKopie'].str.extract('(\w[\w .-]*,\s*\w[\w .$-]*[\w\.])')
#
#Erläuterung der RegEx: Das definierte Muster muss mit einem Zeichen (Buchstaben oder....) beginnen (also nicht mit einem Leerzeichen). 
#Dann folgt ein Zeichen (Buchstaben oder.... , Anzahl 1-n. Dann folgt ein Komma. Danach ein Blank, der 0-n mal 
#vorkommen kann. Gefolgt von Zeichen, die Buchstaben oder ....
#sein können, Anzahl 1-n.

# %%
dfCBSneu.head(10)
# Out:
#           PPN          Verfasser  \
# 0  1733687696    Kranert, Janina
# 1  1733676007  Liebetrau, Frauke
# 2  1733673482  Qalanawi, Morteza
# 3  1733669124  Schütt, Christine
# 4  1730486541    Sprenger, Armin
# 5  1729857345       Knipp, Liisa
# 6  1729822894    Hofmann, Robert
# 7  1729195466      Brand, Janine
# 8  1729181589       Georg, Marie
# 9  172915655X  Buchholz, Jeannie
#
#                                            sonstPers  \
# 0  Dreier-Wolfgramm, Adina [AkademischeR Betreuer...
# 1  Richter, Miriam Tariba ; ID: gnd/135747341; He...
# 2  Stratmeyer, Peter *1955-* ; ID: gnd/123647495;...
# 3  Dreier-Wolfgramm, Adina [AkademischeR Betreuer...
# 4  Witt, Gesine [AkademischeR BetreuerIn]; Kröger...
# 5  Ullrich, Oliver [AkademischeR BetreuerIn]; Kut...
# 6  Petersen-Ewert, Corinna ; ID: gnd/1148965343; ...
# 7  Richter, Miriam Tariba ; ID: gnd/135747341; Be...
# 8  Dreier-Wolfgramm, Adina [AkademischeR Betreuer...
# 9  Dreier-Wolfgramm, Adina [AkademischeR Betreuer...
#
#                                                Titel  \
# 0  Digitale Pflegesprechstunden in der Primärvers...
# 1  Integrationsmaßnahmen zur Förderung der Fach- ...
# 2  Bindungsfördernde Arbeitsbedingungen innerhalb...
# 3  Skills Lab Training in der akademischen Pflege...
# 4  Freisetzung von Schadstoffen in die Umwelt dur...
# 5  Klonierung, heterologe Expression und subzellu...
# 6  Burnout bei Pflegefachkräften in der stationär...
# 7  Pflegerische Förderung der Bindungsentwicklung...
# 8  Konzepte und Lerneffekte für interprofessionel...
# 9  Digitalisierung der Pflegedokumentation in Kra...
#
#                                     RefID_plus_KoRef  \
# 0              Dehning, Kathrin ; ID: gnd/1193095301
# 1   ID: gnd/135747341; Helfrich, Silke [Akademisc...
# 2   ID: gnd/123647495; Tamm, Lars [AkademischeR B...
# 3              Dehning, Kathrin ; ID: gnd/1193095301
# 4           Kröger, Denise [AkademischeR BetreuerIn]
# 5      Kutsche, Kerstin *1965-* ; ID: gnd/1027478948
# 6   ID: gnd/1148965343; Tamm, Lars [AkademischeR ...
# 7   ID: gnd/135747341; Behrens, Katrin [Akademisc...
# 8              Dehning, Kathrin ; ID: gnd/1193095301
# 9              Dehning, Kathrin ; ID: gnd/1193095301
#
#                                                  Ref                 RefKopie
# 0  Dreier-Wolfgramm, Adina [AkademischeR BetreuerIn]  Dreier-Wolfgramm, Adina
# 1                            Richter, Miriam Tariba    Richter, Miriam Tariba
# 2                         Stratmeyer, Peter *1955-*         Stratmeyer, Peter
# 3  Dreier-Wolfgramm, Adina [AkademischeR BetreuerIn]  Dreier-Wolfgramm, Adina
# 4             Witt, Gesine [AkademischeR BetreuerIn]             Witt, Gesine
# 5          Ullrich, Oliver [AkademischeR BetreuerIn]          Ullrich, Oliver
# 6                           Petersen-Ewert, Corinna   Petersen-Ewert, Corinna
# 7                            Richter, Miriam Tariba    Richter, Miriam Tariba
# 8  Dreier-Wolfgramm, Adina [AkademischeR BetreuerIn]  Dreier-Wolfgramm, Adina
# 9  Dreier-Wolfgramm, Adina [AkademischeR BetreuerIn]  Dreier-Wolfgramm, Adina

# %%
#Nun das gleiche für die Spalte RefID_plus_KoRef" 
dfCBSneu['RefID_plus_KoRefKopie'] = dfCBSneu['RefID_plus_KoRef']
dfCBSneu['RefID_plus_KoRefKopie'] = dfCBSneu['RefID_plus_KoRefKopie'].str.extract('(\w[\w .-]*,\s*\w[\w .$-]*[\w\.])')

# %%
dfCBSneu.head()
# Out:
#           PPN          Verfasser  \
# 0  1733687696    Kranert, Janina
# 1  1733676007  Liebetrau, Frauke
# 2  1733673482  Qalanawi, Morteza
# 3  1733669124  Schütt, Christine
# 4  1730486541    Sprenger, Armin
#
#                                            sonstPers  \
# 0  Dreier-Wolfgramm, Adina [AkademischeR Betreuer...
# 1  Richter, Miriam Tariba ; ID: gnd/135747341; He...
# 2  Stratmeyer, Peter *1955-* ; ID: gnd/123647495;...
# 3  Dreier-Wolfgramm, Adina [AkademischeR Betreuer...
# 4  Witt, Gesine [AkademischeR BetreuerIn]; Kröger...
#
#                                                Titel  \
# 0  Digitale Pflegesprechstunden in der Primärvers...
# 1  Integrationsmaßnahmen zur Förderung der Fach- ...
# 2  Bindungsfördernde Arbeitsbedingungen innerhalb...
# 3  Skills Lab Training in der akademischen Pflege...
# 4  Freisetzung von Schadstoffen in die Umwelt dur...
#
#                                     RefID_plus_KoRef  \
# 0              Dehning, Kathrin ; ID: gnd/1193095301
# 1   ID: gnd/135747341; Helfrich, Silke [Akademisc...
# 2   ID: gnd/123647495; Tamm, Lars [AkademischeR B...
# 3              Dehning, Kathrin ; ID: gnd/1193095301
# 4           Kröger, Denise [AkademischeR BetreuerIn]
#
#                                                  Ref                 RefKopie  \
# 0  Dreier-Wolfgramm, Adina [AkademischeR BetreuerIn]  Dreier-Wolfgramm, Adina
# 1                            Richter, Miriam Tariba    Richter, Miriam Tariba
# 2                         Stratmeyer, Peter *1955-*         Stratmeyer, Peter
# 3  Dreier-Wolfgramm, Adina [AkademischeR BetreuerIn]  Dreier-Wolfgramm, Adina
# 4             Witt, Gesine [AkademischeR BetreuerIn]             Witt, Gesine
#
#   RefID_plus_KoRefKopie
# 0      Dehning, Kathrin
# 1       Helfrich, Silke
# 2            Tamm, Lars
# 3      Dehning, Kathrin
# 4        Kröger, Denise

# %%
#Teilweise sind zwei Ko-Referent:innen vorhanden. Diese werden leider mit entfernt.

# %%
#Als excel-Datei speichern und anschauen: 
dfCBSneu.to_excel("../data/CBSneuBereinigt.xlsx")

# %%
#Bei den Namenszusätzen (von oder van) wird jetzt auch "$c" ausgegeben. Dies soll im ganzen Dataframe entfernt
#werden. Mit der Methode replace() soll das "$c" durch ein Leerzeichen ersetzt werden.
dfCBSneu = dfCBSneu.replace(r"\$c"," ", regex=True)

# %%
#Als excel-Datei speichern und anschauen: 
dfCBSneu.to_excel("../data/CBSneuBereinigt2.xlsx")

# %% [markdown]
# # 2. Die Reposit-Datei einlesen, untersuchen und bearbeiten

# %%
dfReposit = pd.read_excel("../data/AbschlussarbeitenReposit.xlsx")

# %%
#Alle vorhandenen Spalten werden mit ...max_columns, None... angezeigt 
pd.set_option('max_columns', None)
dfReposit.head()
# Out:
#      id      collection dc.contributor.advisor dc.contributor.author  \
# 0  5132  20.500.12738/6                    NaN                   NaN
# 1  5360  20.500.12738/6                    NaN                   NaN
# 2  5134  20.500.12738/6                    NaN                   NaN
# 3  5376  20.500.12738/6                    NaN                   NaN
# 4  5377  20.500.12738/6                    NaN                   NaN
#
#              dc.contributor.author[] dc.contributor.other[]  \
# 0      Discher, Annika::rp06916::600                    NaN
# 1  Eickhoff, Sebastian::rp07132::600                    NaN
# 2      Richter, Sandra::rp06917::600                    NaN
# 3      Knudsen, Martin::rp07147::600                    NaN
# 4   Zakarwal, Schafiqa::rp07148::600                    NaN
#
#   dc.contributorCorporate.other[] dc.date.created  dc.date.created[]  \
# 0                             NaN             NaN             2010.0
# 1                             NaN             NaN             2011.0
# 2                             NaN             NaN             2010.0
# 3                             NaN             NaN             2011.0
# 4                             NaN             NaN             2011.0
#
#   dc.date.issued dc.date.issued[] dc.description.abstract[]  \
# 0            NaN       2010-06-28                       NaN
# 1            NaN       2011-06-22                       NaN
# 2            NaN       2010-06-28                       NaN
# 3            NaN       2011-06-30                       NaN
# 4            NaN       2011-06-30                       NaN
#
#                          dc.description.abstract[de]  \
# 0                            kein Abstract vorhanden
# 1  In dieser Arbeit wird ein Sensor-Aktor-System ...
# 2  Die vorliegende Bachelorarbeit beschäftigt sic...
# 3  Gegenstand dieser Arbeit ist die Planung und E...
# 4  Gegenstand der vorliegenden Arbeit ist die Ent...
#
#                          dc.description.abstract[en]  \
# 0                                                NaN
# 1  This thesis deals with the development of an S...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   dc.description.abstract[en_US] dc.description.abstract[mis]  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#                                    dc.identifier.uri dc.identifier.urn[]  \
# 0  https://reposit.haw-hamburg.de/handle/20.500.1...                 NaN
# 1  https://reposit.haw-hamburg.de/handle/20.500.1...                 NaN
# 2  https://reposit.haw-hamburg.de/handle/20.500.1...                 NaN
# 3  https://reposit.haw-hamburg.de/handle/20.500.1...                 NaN
# 4  https://reposit.haw-hamburg.de/handle/20.500.1...                 NaN
#
#   dc.language.iso[de] dc.language.iso[en] dc.language.iso[en_US]  \
# 0                  de                 NaN                    NaN
# 1                  de                 NaN                    NaN
# 2                  de                 NaN                    NaN
# 3                  de                 NaN                    NaN
# 4                  de                 NaN                    NaN
#
#   dc.relation.isreplacedby dc.rights.cc[] dc.rights.cc[en_US] dc.subject.ddc  \
# 0                      NaN            NaN                 NaN            NaN
# 1                      NaN            NaN                 NaN            NaN
# 2                      NaN            NaN                 NaN            NaN
# 3                      NaN            NaN                 NaN            NaN
# 4                      NaN            NaN                 NaN            NaN
#
#                                     dc.subject.ddc[] dc.subject.ddc[en_US]  \
# 0  360 Soziale Probleme, Sozialdienste, Versicher...                   NaN
# 1                                     004 Informatik                   NaN
# 2  300 Sozialwissenschaften, Soziologie, Anthropo...                   NaN
# 3      020 Bibliotheks- und Informationswissenschaft                   NaN
# 4      020 Bibliotheks- und Informationswissenschaft                   NaN
#
#   dc.subject.gnd                                   dc.subject.gnd[]  \
# 0            NaN       Essstörung||Mädchen||Prävention||Entwicklung
# 1            NaN                               Eingebettetes System
# 2            NaN  Kindertagesstätte||Mitarbeiter||Zufriedenheit|...
# 3            NaN               Mobiles Internet||World Wide Web 2.0
# 4            NaN            Medienkonsum||Afghanischer Jugendlicher
#
#   dc.subject[de] dc.subject[en] dc.subject[en_US] dc.title.alternative[en]  \
# 0            NaN            NaN               NaN                      NaN
# 1            NaN            NaN               NaN                      NaN
# 2            NaN            NaN               NaN                      NaN
# 3            NaN            NaN               NaN                      NaN
# 4            NaN            NaN               NaN                      NaN
#
#                                         dc.title[de] dc.title[en]  \
# 0  Zur Bedeutung der Gesellschaft für die Entwick...          NaN
# 1  Ein modulares Sensor-Aktor-System für mobile R...          NaN
# 2  Gesundheitsauswirkungen des Setting-Ansatzes i...          NaN
# 3  Realisierung eines mobilen Informationsdienste...          NaN
# 4  Afghanische Kultur ade- Interviewgestützte Bef...          NaN
#
#   dc.title[en_US] dc.type                  dc.type.casrai    dc.type.dini  \
# 0             NaN     NaN  Supervised Student Publication  bachelorThesis
# 1             NaN     NaN  Supervised Student Publication  bachelorThesis
# 2             NaN     NaN  Supervised Student Publication  bachelorThesis
# 3             NaN     NaN  Supervised Student Publication  bachelorThesis
# 4             NaN     NaN  Supervised Student Publication  bachelorThesis
#
#    dc.type.driver dc.type.status                         dc.type.status[]  \
# 0  bachelorThesis            NaN  info:eu-repo/semantics/publishedVersion
# 1  bachelorThesis            NaN  info:eu-repo/semantics/publishedVersion
# 2  bachelorThesis            NaN  info:eu-repo/semantics/publishedVersion
# 3  bachelorThesis            NaN  info:eu-repo/semantics/publishedVersion
# 4  bachelorThesis            NaN  info:eu-repo/semantics/publishedVersion
#
#   dc.type.status[en_US] dc.type.thesis dc.type.thesis[] dc.type.thesis[en_US]  \
# 0                   NaN            NaN   bachelorThesis                   NaN
# 1                   NaN            NaN   bachelorThesis                   NaN
# 2                   NaN            NaN   bachelorThesis                   NaN
# 3                   NaN            NaN   bachelorThesis                   NaN
# 4                   NaN            NaN   bachelorThesis                   NaN
#
#   dc.type[] dc.type[en_US] dcterms.DCMIType local.comment openaire.rights  \
# 0    Thesis            NaN             Text           NaN             NaN
# 1    Thesis            NaN             Text           NaN             NaN
# 2    Thesis            NaN             Text           NaN             NaN
# 3    Thesis            NaN             Text           NaN             NaN
# 4    Thesis            NaN             Text           NaN             NaN
#
#                           openaire.rights[] openaire.rights[en_US]  \
# 0  http://purl.org/coar/access_right/c_abf2                    NaN
# 1  http://purl.org/coar/access_right/c_abf2                    NaN
# 2  http://purl.org/coar/access_right/c_abf2                    NaN
# 3  http://purl.org/coar/access_right/c_abf2                    NaN
# 4  http://purl.org/coar/access_right/c_abf2                    NaN
#
#   thesis.grantor.department  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
#                          thesis.grantor.department[]  \
# 0            Department Soziale Arbeit::ou00050::600
# 1                Department Informatik::ou00045::600
# 2  Department Gesundheitswissenschaften::ou00038:...
# 3               Department Information::ou00034::600
# 4               Department Information::ou00034::600
#
#   thesis.grantor.department[en_US] thesis.grantor.place  \
# 0                              NaN                  NaN
# 1                              NaN                  NaN
# 2                              NaN                  NaN
# 3                              NaN                  NaN
# 4                              NaN                  NaN
#
#   thesis.grantor.place[] thesis.grantor.universityOrInstitution  \
# 0                Hamburg                                    NaN
# 1                Hamburg                                    NaN
# 2                Hamburg                                    NaN
# 3                Hamburg                                    NaN
# 4                Hamburg                                    NaN
#
#             thesis.grantor.universityOrInstitution[]  \
# 0  Hochschule für angewandte Wissenschaften Hambu...
# 1  Hochschule für angewandte Wissenschaften Hambu...
# 2  Hochschule für angewandte Wissenschaften Hambu...
# 3  Hochschule für angewandte Wissenschaften Hambu...
# 4  Hochschule für angewandte Wissenschaften Hambu...
#
#   thesis.grantor.universityOrInstitution[en_US] tuhh.contributor.referee  \
# 0                                           NaN                      NaN
# 1                                           NaN                      NaN
# 2                                           NaN                      NaN
# 3                                           NaN                      NaN
# 4                                           NaN                      NaN
#
#    tuhh.gvk.ppn tuhh.gvk.ppn[] tuhh.note.extern tuhh.note.extern[]  \
# 0           NaN      630150826              NaN       publ-mit-pod
# 1           NaN      662632974              NaN       publ-mit-pod
# 2           NaN      630155089              NaN       publ-mit-pod
# 3           NaN      663400872              NaN       publ-mit-pod
# 4           NaN      66340200X              NaN       publ-mit-pod
#
#    tuhh.note.intern  tuhh.note.intern[] tuhh.oai.show[en_US]  tuhh.opus.id  \
# 0               NaN                 1.0                 True           NaN
# 1               NaN                 1.0                 True           NaN
# 2               NaN                 1.0                 True           NaN
# 3               NaN                 1.0                 True           NaN
# 4               NaN                 1.0                 True           NaN
#
#    tuhh.opus.id[] tuhh.publication.institute  \
# 0          1025.0                        NaN
# 1          1268.0                        NaN
# 2          1027.0                        NaN
# 3          1284.0                        NaN
# 4          1285.0                        NaN
#
#                         tuhh.publication.institute[]  \
# 0            Department Soziale Arbeit::ou00050::600
# 1                Department Informatik::ou00045::600
# 2  Department Gesundheitswissenschaften::ou00038:...
# 3               Department Information::ou00034::600
# 4               Department Information::ou00034::600
#
#   tuhh.publication.institute[en_US]   tuhh.type.opus tuhh.uploader.email  \
# 0                               NaN  Bachelor Thesis                 NaN
# 1                               NaN  Bachelor Thesis                 NaN
# 2                               NaN  Bachelor Thesis                 NaN
# 3                               NaN  Bachelor Thesis                 NaN
# 4                               NaN  Bachelor Thesis                 NaN
#
#               tuhh.uploader.email[]
# 0  kerstin.hauschild@haw-hamburg.de
# 1                                 @
# 2      susanne.gassl@haw-hamburg.de
# 3  detlev.dannenberg@haw-hamburg.de
# 4  detlev.dannenberg@haw-hamburg.de

# %%
dfReposit.columns
# Out:
# Index(['id', 'collection', 'dc.contributor.advisor', 'dc.contributor.author',
#        'dc.contributor.author[]', 'dc.contributor.other[]',
#        'dc.contributorCorporate.other[]', 'dc.date.created',
#        'dc.date.created[]', 'dc.date.issued', 'dc.date.issued[]',
#        'dc.description.abstract[]', 'dc.description.abstract[de]',
#        'dc.description.abstract[en]', 'dc.description.abstract[en_US]',
#        'dc.description.abstract[mis]', 'dc.identifier.uri',
#        'dc.identifier.urn[]', 'dc.language.iso[de]', 'dc.language.iso[en]',
#        'dc.language.iso[en_US]', 'dc.relation.isreplacedby', 'dc.rights.cc[]',
#        'dc.rights.cc[en_US]', 'dc.subject.ddc', 'dc.subject.ddc[]',
#        'dc.subject.ddc[en_US]', 'dc.subject.gnd', 'dc.subject.gnd[]',
#        'dc.subject[de]', 'dc.subject[en]', 'dc.subject[en_US]',
#        'dc.title.alternative[en]', 'dc.title[de]', 'dc.title[en]',
#        'dc.title[en_US]', 'dc.type', 'dc.type.casrai', 'dc.type.dini',
#        'dc.type.driver', 'dc.type.status', 'dc.type.status[]',
#        'dc.type.status[en_US]', 'dc.type.thesis', 'dc.type.thesis[]',
#        'dc.type.thesis[en_US]', 'dc.type[]', 'dc.type[en_US]',
#        'dcterms.DCMIType', 'local.comment', 'openaire.rights',
#        'openaire.rights[]', 'openaire.rights[en_US]',
#        'thesis.grantor.department', 'thesis.grantor.department[]',
#        'thesis.grantor.department[en_US]', 'thesis.grantor.place',
#        'thesis.grantor.place[]', 'thesis.grantor.universityOrInstitution',
#        'thesis.grantor.universityOrInstitution[]',
#        'thesis.grantor.universityOrInstitution[en_US]',
#        'tuhh.contributor.referee', 'tuhh.gvk.ppn', 'tuhh.gvk.ppn[]',
#        'tuhh.note.extern', 'tuhh.note.extern[]', 'tuhh.note.intern',
#        'tuhh.note.intern[]', 'tuhh.oai.show[en_US]', 'tuhh.opus.id',
#        'tuhh.opus.id[]', 'tuhh.publication.institute',
#        'tuhh.publication.institute[]', 'tuhh.publication.institute[en_US]',
#        'tuhh.type.opus', 'tuhh.uploader.email', 'tuhh.uploader.email[]'],
#       dtype='object')

# %%
#Für die spätere Weiterverarbeitng müssen nur die Spalten id und collection erhalten bleiben. Die Betreuer*innen
#sollen in die Spalten "dc.contributor.advisor' bzw. 'tuhh.contributor.referee'. Zur Kontrolle
#sollen auch Autor*in (Spalte 'dc.contributor.author[]') und der Titel (Spalte 'dc.title[de]' bzw.
# 'dc.title[en]') bleiben. Und natürlich die Spalte mit dem Identifikator (ppn): 'tuhh.gvk.ppn[]'
#D.h. es sollen insg. 8 Spalten bestehen bleiben. 
#Die nicht benötigten Spalten mit "drop" löschen und Ergebnis in eine neue Variable schreiben:
dfReposit8Spalten = dfReposit.drop(['dc.contributor.author', 'dc.contributor.other[]',
       'dc.contributorCorporate.other[]', 'dc.date.created',
       'dc.date.created[]', 'dc.date.issued', 'dc.date.issued[]',
       'dc.description.abstract[]', 'dc.description.abstract[de]',
       'dc.description.abstract[en]', 'dc.description.abstract[en_US]',
       'dc.description.abstract[mis]', 'dc.identifier.uri',
       'dc.identifier.urn[]', 'dc.language.iso[de]', 'dc.language.iso[en]',
       'dc.language.iso[en_US]', 'dc.relation.isreplacedby', 'dc.rights.cc[]',
       'dc.rights.cc[en_US]', 'dc.subject.ddc', 'dc.subject.ddc[]',
       'dc.subject.ddc[en_US]', 'dc.subject.gnd', 'dc.subject.gnd[]',
       'dc.subject[de]', 'dc.subject[en]', 'dc.subject[en_US]',
       'dc.title.alternative[en]',
       'dc.title[en_US]', 'dc.type', 'dc.type.casrai', 'dc.type.dini',
       'dc.type.driver', 'dc.type.status', 'dc.type.status[]',
       'dc.type.status[en_US]', 'dc.type.thesis', 'dc.type.thesis[]',
       'dc.type.thesis[en_US]', 'dc.type[]', 'dc.type[en_US]',
       'dcterms.DCMIType', 'local.comment', 'openaire.rights',
       'openaire.rights[]', 'openaire.rights[en_US]',
       'thesis.grantor.department', 'thesis.grantor.department[]',
       'thesis.grantor.department[en_US]', 'thesis.grantor.place',
       'thesis.grantor.place[]', 'thesis.grantor.universityOrInstitution',
       'thesis.grantor.universityOrInstitution[]',
       'thesis.grantor.universityOrInstitution[en_US]',
        'tuhh.gvk.ppn', 'tuhh.note.extern', 'tuhh.note.extern[]', 'tuhh.note.intern',
       'tuhh.note.intern[]', 'tuhh.oai.show[en_US]', 'tuhh.opus.id',
       'tuhh.opus.id[]', 'tuhh.publication.institute',
       'tuhh.publication.institute[]', 'tuhh.publication.institute[en_US]',
       'tuhh.type.opus', 'tuhh.uploader.email', 'tuhh.uploader.email[]'], axis=1)

# %%
dfReposit8Spalten.head()
# Out:
#      id      collection dc.contributor.advisor  \
# 0  5132  20.500.12738/6                    NaN
# 1  5360  20.500.12738/6                    NaN
# 2  5134  20.500.12738/6                    NaN
# 3  5376  20.500.12738/6                    NaN
# 4  5377  20.500.12738/6                    NaN
#
#              dc.contributor.author[]  \
# 0      Discher, Annika::rp06916::600
# 1  Eickhoff, Sebastian::rp07132::600
# 2      Richter, Sandra::rp06917::600
# 3      Knudsen, Martin::rp07147::600
# 4   Zakarwal, Schafiqa::rp07148::600
#
#                                         dc.title[de] dc.title[en]  \
# 0  Zur Bedeutung der Gesellschaft für die Entwick...          NaN
# 1  Ein modulares Sensor-Aktor-System für mobile R...          NaN
# 2  Gesundheitsauswirkungen des Setting-Ansatzes i...          NaN
# 3  Realisierung eines mobilen Informationsdienste...          NaN
# 4  Afghanische Kultur ade- Interviewgestützte Bef...          NaN
#
#   tuhh.contributor.referee tuhh.gvk.ppn[]
# 0                      NaN      630150826
# 1                      NaN      662632974
# 2                      NaN      630155089
# 3                      NaN      663400872
# 4                      NaN      66340200X

# %%
#Die Spalte 'tuhh.gvk.ppn[]' in 'PPN' umbenennen 
dfReposit8Spalten.rename(columns={'tuhh.gvk.ppn[]': 'PPN'}, inplace=True)

# %%
dfReposit8Spalten.head()
# Out:
#      id      collection dc.contributor.advisor  \
# 0  5132  20.500.12738/6                    NaN
# 1  5360  20.500.12738/6                    NaN
# 2  5134  20.500.12738/6                    NaN
# 3  5376  20.500.12738/6                    NaN
# 4  5377  20.500.12738/6                    NaN
#
#              dc.contributor.author[]  \
# 0      Discher, Annika::rp06916::600
# 1  Eickhoff, Sebastian::rp07132::600
# 2      Richter, Sandra::rp06917::600
# 3      Knudsen, Martin::rp07147::600
# 4   Zakarwal, Schafiqa::rp07148::600
#
#                                         dc.title[de] dc.title[en]  \
# 0  Zur Bedeutung der Gesellschaft für die Entwick...          NaN
# 1  Ein modulares Sensor-Aktor-System für mobile R...          NaN
# 2  Gesundheitsauswirkungen des Setting-Ansatzes i...          NaN
# 3  Realisierung eines mobilen Informationsdienste...          NaN
# 4  Afghanische Kultur ade- Interviewgestützte Bef...          NaN
#
#   tuhh.contributor.referee        PPN
# 0                      NaN  630150826
# 1                      NaN  662632974
# 2                      NaN  630155089
# 3                      NaN  663400872
# 4                      NaN  66340200X

# %%
dfReposit8Spalten.columns
# Out:
# Index(['id', 'collection', 'dc.contributor.advisor', 'dc.contributor.author[]',
#        'dc.title[de]', 'dc.title[en]', 'tuhh.contributor.referee', 'PPN'],
#       dtype='object')

# %%
dfReposit8Spalten.shape
# Out:
# (4882, 8)

# %%
#Wie viele Datensätze enthalten keine PPN (sondern NaN)?
dfReposit8Spalten['PPN'].isna().sum()
# Out:
# 168

# %%
#Diese 168 Zeilen löschen und das Ergebnis in eine neue Variable schreiben
dfRepo = dfReposit8Spalten.dropna(subset=['PPN'])

# %%
dfRepo.shape
# Out:
# (4714, 8)

# %%
#Spalte mit PPNs genauer betrachten mit 
#df.Repo.PPN 
#Hier nur die ersten 5 Zeilen.
dfRepo.PPN.head(5)
# Out:
# 0    630150826
# 1    662632974
# 2    630155089
# 3    663400872
# 4    66340200X
# Name: PPN, dtype: object

# %%
#Teilweise sind zwei PPNs vorhanden, z.B. Zeile 817 oder 985. Prüfung ergibt, dass die erste PPN die korrekte ist. 
#D.h. die zweiten PPNs sollen gelöscht werden. Dazu wird die zweite PPN mithilfe einer RegEx gefunden (es wird nach einer 
#Ziffernfolge gesucht, die ggfs. mit einem X endet) und mit str.extract entfernt.
#Die Warnung kann ignoriert werden. 
dfRepo['einePPN'] = dfRepo['PPN'].str.extract('(\d+X?)')
# Out:
# <ipython-input-277-bfcd37226a8c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfRepo['einePPN'] = dfRepo['PPN'].str.extract('(\d+X?)')

# %%
#Spalte mit PPNs genauer betrachten mit 
#df.Repo.einePPN 
#Hier nur die ersten 5 Zeilen.
dfRepo['einePPN'].head()
# Out:
# 0    630150826
# 1    662632974
# 2    630155089
# 3    663400872
# 4    66340200X
# Name: einePPN, dtype: object

# %%
dfRepo.head(5)
# Out:
#      id      collection dc.contributor.advisor  \
# 0  5132  20.500.12738/6                    NaN
# 1  5360  20.500.12738/6                    NaN
# 2  5134  20.500.12738/6                    NaN
# 3  5376  20.500.12738/6                    NaN
# 4  5377  20.500.12738/6                    NaN
#
#              dc.contributor.author[]  \
# 0      Discher, Annika::rp06916::600
# 1  Eickhoff, Sebastian::rp07132::600
# 2      Richter, Sandra::rp06917::600
# 3      Knudsen, Martin::rp07147::600
# 4   Zakarwal, Schafiqa::rp07148::600
#
#                                         dc.title[de] dc.title[en]  \
# 0  Zur Bedeutung der Gesellschaft für die Entwick...          NaN
# 1  Ein modulares Sensor-Aktor-System für mobile R...          NaN
# 2  Gesundheitsauswirkungen des Setting-Ansatzes i...          NaN
# 3  Realisierung eines mobilen Informationsdienste...          NaN
# 4  Afghanische Kultur ade- Interviewgestützte Bef...          NaN
#
#   tuhh.contributor.referee        PPN    einePPN
# 0                      NaN  630150826  630150826
# 1                      NaN  662632974  662632974
# 2                      NaN  630155089  630155089
# 3                      NaN  663400872  663400872
# 4                      NaN  66340200X  66340200X

# %%
#Die alte PPN-Spalte löschen und "einePPN" in "PPN" umbenennen
dfRepo = dfRepo.drop(['PPN'], axis=1)
dfRepo = dfRepo.rename(columns={'einePPN': 'PPN'})

# %%
dfRepo.head(2)
# Out:
#      id      collection dc.contributor.advisor  \
# 0  5132  20.500.12738/6                    NaN
# 1  5360  20.500.12738/6                    NaN
#
#              dc.contributor.author[]  \
# 0      Discher, Annika::rp06916::600
# 1  Eickhoff, Sebastian::rp07132::600
#
#                                         dc.title[de] dc.title[en]  \
# 0  Zur Bedeutung der Gesellschaft für die Entwick...          NaN
# 1  Ein modulares Sensor-Aktor-System für mobile R...          NaN
#
#   tuhh.contributor.referee        PPN
# 0                      NaN  630150826
# 1                      NaN  662632974

# %%
#Vergleich der Spalten mit der CBS-Datei
dfCBSneu.head(2)
# Out:
#           PPN          Verfasser  \
# 0  1733687696    Kranert, Janina
# 1  1733676007  Liebetrau, Frauke
#
#                                            sonstPers  \
# 0  Dreier-Wolfgramm, Adina [AkademischeR Betreuer...
# 1  Richter, Miriam Tariba ; ID: gnd/135747341; He...
#
#                                                Titel  \
# 0  Digitale Pflegesprechstunden in der Primärvers...
# 1  Integrationsmaßnahmen zur Förderung der Fach- ...
#
#                                     RefID_plus_KoRef  \
# 0              Dehning, Kathrin ; ID: gnd/1193095301
# 1   ID: gnd/135747341; Helfrich, Silke [Akademisc...
#
#                                                  Ref                 RefKopie  \
# 0  Dreier-Wolfgramm, Adina [AkademischeR BetreuerIn]  Dreier-Wolfgramm, Adina
# 1                            Richter, Miriam Tariba    Richter, Miriam Tariba
#
#   RefID_plus_KoRefKopie
# 0      Dehning, Kathrin
# 1       Helfrich, Silke

# %% [markdown]
# # 3. Beide Dateien an der PPNn mergen

# %% [markdown]
# Vor dem Mergen muss bei dfCBS die PPN-Spalte in String-Werte umgewandelt werden.

# %%
#Weil bei vorhgerigen Versuchen eine Fehlemeldung kam, vor dem Mergen ein Re-Indexing durchführen:
dfCBSneu = dfCBSneu.reindex()
dfCBSneu['PPN'] = pd.Series(dfCBSneu['PPN'], dtype="string")

# %%
#Nun Prüfen, wie viele Übereinstimmungen in den jeweiligen PPN-Spalten der beiden Dateien vorkommen. 
#Dazu die PPN-Spalten in String umwandeln:
set_1 = set(dfRepo.PPN.astype("str"))
set_2 = set(dfCBSneu.PPN.astype("str"))
len(set_2.intersection(set_1))
# Out:
# 4671

# %%
#Erster Merge-Versuch als "inner"-Merge, d.h. es bleiben nur die Zeilen erhalten, bei denen die PPNs übereinstimmen:
Merge1 = dfRepo.merge(dfCBSneu, on='PPN', how='inner')

# %%
Merge1.shape
# Out:
# (4672, 15)

# %%
Merge1.head(15)
# Out:
#       id      collection dc.contributor.advisor  \
# 0   5132  20.500.12738/6                    NaN
# 1   5360  20.500.12738/6                    NaN
# 2   5134  20.500.12738/6                    NaN
# 3   5376  20.500.12738/6                    NaN
# 4   5377  20.500.12738/6                    NaN
# 5   5136  20.500.12738/6                    NaN
# 6   5378  20.500.12738/6                    NaN
# 7   5379  20.500.12738/6                    NaN
# 8   5369  20.500.12738/6                    NaN
# 9   5368  20.500.12738/6                    NaN
# 10  5380  20.500.12738/6                    NaN
# 11  5370  20.500.12738/6                    NaN
# 12  5381  20.500.12738/6                    NaN
# 13  5382  20.500.12738/6                    NaN
# 14  5562  20.500.12738/6                    NaN
#
#                        dc.contributor.author[]  \
# 0                Discher, Annika::rp06916::600
# 1            Eickhoff, Sebastian::rp07132::600
# 2                Richter, Sandra::rp06917::600
# 3                Knudsen, Martin::rp07147::600
# 4             Zakarwal, Schafiqa::rp07148::600
# 5                Sundas, Claudia::rp06919::600
# 6               Jeretzky, Nicole::rp07149::600
# 7   Tamancoldi Lechte, Yasmin N.::rp07150::600
# 8               Hilbig, Svetlana::rp07141::600
# 9               Liedtke, Andreas::rp07140::600
# 10              Haeupler, Yvonne::rp07151::600
# 11           Keunecke, Elisabeth::rp07142::600
# 12                  Häse, Sandra::rp07152::600
# 13              Erdmann, Patrick::rp07153::600
# 14                Thom, Benjamin::rp07325::600
#
#                                          dc.title[de] dc.title[en]  \
# 0   Zur Bedeutung der Gesellschaft für die Entwick...          NaN
# 1   Ein modulares Sensor-Aktor-System für mobile R...          NaN
# 2   Gesundheitsauswirkungen des Setting-Ansatzes i...          NaN
# 3   Realisierung eines mobilen Informationsdienste...          NaN
# 4   Afghanische Kultur ade- Interviewgestützte Bef...          NaN
# 5   Modellprojekt „filmreif“ : Konzeption eines in...          NaN
# 6   Magie der Marke : Rezeptionsstudie zu Charakte...          NaN
# 7   Social Media Marketing in der Kommunikationspo...          NaN
# 8   Entwicklerportal als Geschäftsmodell 2.0: sein...          NaN
# 9   Realisierung eines robusten Verfahrens zur Ide...          NaN
# 10  Bibliothekare in der Selbstständigkeit - Erfah...          NaN
# 11  digital natives- mit Medien aufwachsen: Eine F...          NaN
# 12  Nationalsozialistische Literatur in Bibliothek...          NaN
# 13  p2p – Bedrohung und Chance : Analysen zur Entw...          NaN
# 14  Konzeption und Realisierung eines interaktiven...          NaN
#
#    tuhh.contributor.referee        PPN                     Verfasser  \
# 0                       NaN  630150826               Discher, Annika
# 1                       NaN  662632974           Eickhoff, Sebastian
# 2                       NaN  630155089               Richter, Sandra
# 3                       NaN  663400872               Knudsen, Martin
# 4                       NaN  66340200X            Zakarwal, Schafiqa
# 5                       NaN  51844483X               Sundas, Claudia
# 6                       NaN  663403200              Jeretzky, Nicole
# 7                       NaN  663404932  Tamancoldi Lechte, Yasmin N.
# 8                       NaN  663322782              Hilbig, Svetlana
# 9                       NaN  663207673              Liedtke, Andreas
# 10                      NaN  663406005              Haeupler, Yvonne
# 11                      NaN  66332503X           Keunecke, Elisabeth
# 12                      NaN  663406943                  Häse, Sandra
# 13                      NaN  52368519X              Erdmann, Patrick
# 14                      NaN  682505870                Thom, Benjamin
#
#                                             sonstPers  \
# 0   Schwarting, Frauke [Ref.]; Güntner, Simon [Ko-...
# 1     Pareigis, Stephan [Ref.]; Korf, Franz [Ko-Ref.]
# 2                   Färber, Christine; Kliche, Thomas
# 3    Gennis, Martin [Ref.]; Mintert, Stefan [Ko-Ref.]
# 4   Schmidt, Ralph [Ref.]; Kübler, Hans-Dieter [Ko...
# 5   Biebrach-Plett, Ulla [Ref.]; Lüdemann, Otto [K...
# 6    Schmidt, Ralph [Ref.]; Gundlach, Hardy [Ko-Ref.]
# 7   Hofmann, Ulrich [Ref.]; Gundlach, Hardy [Ko-Ref.]
# 8   Lewandowski, Dirk [Ref.]; Gundlach, Hardy [Ko-...
# 9   Meisel, Andreas [Ref.]; Baran, Reinhard [Ko-Ref.]
# 10  Krauß-Leichert, Ute [Ref.]; Schade, Frauke [Ko...
# 11  Kübler, Hans-Dieter [Ref.]; Debacher, Uwe [Ko-...
# 12  Verch, Ulrike [Ref.]; Gläser, Christine [Ko-Ref.]
# 13  Schmidt, Ralph [Ref.]; Ludwig, Johannes [Ko-Ref.]
# 14      Zukunft, Olaf [Ref.]; Buth, Bettina [Ko-Ref.]
#
#                                                 Titel  \
# 0   Zur Bedeutung der Gesellschaft für die Entwick...
# 1   Ein modulares Sensor-Aktor-System für mobile R...
# 2   Gesundheitsauswirkungen des Setting-Ansatzes i...
# 3   Realisierung eines mobilen Informationsdienste...
# 4                              Afghanische Kultur ade
# 5   Modellprojekt 'filmreif': Konzeption eines int...
# 6                                     Magie der Marke
# 7   Social Media Marketing in der Kommunikationspo...
# 8   Entwicklerportal als Geschäftsmodell 2.0: sein...
# 9   Realisierung eines robusten Verfahrens zur Ide...
# 10             Bibliothekare in der Selbstständigkeit
# 11            Digital natives - mit Medien aufwachsen
# 12   Nationalsozialistische Literatur in Bibliotheken
# 13                         p2p - Bedrohung und Chance
# 14  Konzeption und Realisierung eines interaktiven...
#
#                   RefID_plus_KoRef                          Ref  \
# 0         Güntner, Simon [Ko-Ref.]    Schwarting, Frauke [Ref.]
# 1            Korf, Franz [Ko-Ref.]     Pareigis, Stephan [Ref.]
# 2                   Kliche, Thomas            Färber, Christine
# 3        Mintert, Stefan [Ko-Ref.]        Gennis, Martin [Ref.]
# 4    Kübler, Hans-Dieter [Ko-Ref.]        Schmidt, Ralph [Ref.]
# 5         Lüdemann, Otto [Ko-Ref.]  Biebrach-Plett, Ulla [Ref.]
# 6        Gundlach, Hardy [Ko-Ref.]        Schmidt, Ralph [Ref.]
# 7        Gundlach, Hardy [Ko-Ref.]       Hofmann, Ulrich [Ref.]
# 8        Gundlach, Hardy [Ko-Ref.]     Lewandowski, Dirk [Ref.]
# 9        Baran, Reinhard [Ko-Ref.]       Meisel, Andreas [Ref.]
# 10        Schade, Frauke [Ko-Ref.]   Krauß-Leichert, Ute [Ref.]
# 11         Debacher, Uwe [Ko-Ref.]   Kübler, Hans-Dieter [Ref.]
# 12     Gläser, Christine [Ko-Ref.]         Verch, Ulrike [Ref.]
# 13      Ludwig, Johannes [Ko-Ref.]        Schmidt, Ralph [Ref.]
# 14         Buth, Bettina [Ko-Ref.]         Zukunft, Olaf [Ref.]
#
#                 RefKopie RefID_plus_KoRefKopie
# 0     Schwarting, Frauke        Güntner, Simon
# 1      Pareigis, Stephan           Korf, Franz
# 2      Färber, Christine        Kliche, Thomas
# 3         Gennis, Martin       Mintert, Stefan
# 4         Schmidt, Ralph   Kübler, Hans-Dieter
# 5   Biebrach-Plett, Ulla        Lüdemann, Otto
# 6         Schmidt, Ralph       Gundlach, Hardy
# 7        Hofmann, Ulrich       Gundlach, Hardy
# 8      Lewandowski, Dirk       Gundlach, Hardy
# 9        Meisel, Andreas       Baran, Reinhard
# 10   Krauß-Leichert, Ute        Schade, Frauke
# 11   Kübler, Hans-Dieter         Debacher, Uwe
# 12         Verch, Ulrike     Gläser, Christine
# 13        Schmidt, Ralph      Ludwig, Johannes
# 14         Zukunft, Olaf         Buth, Bettina

# %%
#Als neue Excel-Tabelle speichern, um prüfen zu können:
Merge1.to_excel("../data/Merge1_1.xlsx")
#Ergebnis: Durch das Umwandeln in Srings funktionierte das Mergen von 4660 Datensätze korrekt.

# %%
#Alternativ zu Merge1 nun mit left-join. Dabei bleiben alle Datensätze des "linken" DataFramer erhalten, auch wenn
#kein Zusamenführen anhand der PPN mit dem "rechten" Datensatz möglich ist:
Merge2 = dfRepo.merge(dfCBSneu, on='PPN', how='left', left_index=True)

# %%
Merge2.shape
# Out:
# (4715, 15)

# %%
Merge2.head(3)
# Out:
#           id      collection dc.contributor.advisor  \
# 3965.0  5132  20.500.12738/6                    NaN
# 3695.0  5360  20.500.12738/6                    NaN
# 4020.0  5134  20.500.12738/6                    NaN
#
#                   dc.contributor.author[]  \
# 3965.0      Discher, Annika::rp06916::600
# 3695.0  Eickhoff, Sebastian::rp07132::600
# 4020.0      Richter, Sandra::rp06917::600
#
#                                              dc.title[de] dc.title[en]  \
# 3965.0  Zur Bedeutung der Gesellschaft für die Entwick...          NaN
# 3695.0  Ein modulares Sensor-Aktor-System für mobile R...          NaN
# 4020.0  Gesundheitsauswirkungen des Setting-Ansatzes i...          NaN
#
#        tuhh.contributor.referee        PPN            Verfasser  \
# 3965.0                      NaN  630150826      Discher, Annika
# 3695.0                      NaN  662632974  Eickhoff, Sebastian
# 4020.0                      NaN  630155089      Richter, Sandra
#
#                                                 sonstPers  \
# 3965.0  Schwarting, Frauke [Ref.]; Güntner, Simon [Ko-...
# 3695.0    Pareigis, Stephan [Ref.]; Korf, Franz [Ko-Ref.]
# 4020.0                  Färber, Christine; Kliche, Thomas
#
#                                                     Titel  \
# 3965.0  Zur Bedeutung der Gesellschaft für die Entwick...
# 3695.0  Ein modulares Sensor-Aktor-System für mobile R...
# 4020.0  Gesundheitsauswirkungen des Setting-Ansatzes i...
#
#                  RefID_plus_KoRef                        Ref  \
# 3965.0   Güntner, Simon [Ko-Ref.]  Schwarting, Frauke [Ref.]
# 3695.0      Korf, Franz [Ko-Ref.]   Pareigis, Stephan [Ref.]
# 4020.0             Kliche, Thomas          Färber, Christine
#
#                   RefKopie RefID_plus_KoRefKopie
# 3965.0  Schwarting, Frauke        Güntner, Simon
# 3695.0   Pareigis, Stephan           Korf, Franz
# 4020.0   Färber, Christine        Kliche, Thomas

# %%
#Als neue Excel-Tabelle speichern, um prüfen zu können:
Merge2.to_excel("../data/Merge2_1.xlsx")

# %%
#Den Inhalt der Spalte "RefKopie" in die Spalte "dc.contributor.advisor" kopieren sowie Inhalt der Spalte 
#"RefID_plus_KoRefKopie" in die Spalte "tuhh.contributor.referee" kopieren 
Merge2['dc.contributor.advisor'] = Merge2['RefKopie']
Merge2['tuhh.contributor.referee'] = Merge2['RefID_plus_KoRefKopie']

# %%
Merge2.head(5)
# Out:
#           id      collection dc.contributor.advisor  \
# 3965.0  5132  20.500.12738/6     Schwarting, Frauke
# 3695.0  5360  20.500.12738/6      Pareigis, Stephan
# 4020.0  5134  20.500.12738/6      Färber, Christine
# 3808.0  5376  20.500.12738/6         Gennis, Martin
# 3807.0  5377  20.500.12738/6         Schmidt, Ralph
#
#                   dc.contributor.author[]  \
# 3965.0      Discher, Annika::rp06916::600
# 3695.0  Eickhoff, Sebastian::rp07132::600
# 4020.0      Richter, Sandra::rp06917::600
# 3808.0      Knudsen, Martin::rp07147::600
# 3807.0   Zakarwal, Schafiqa::rp07148::600
#
#                                              dc.title[de] dc.title[en]  \
# 3965.0  Zur Bedeutung der Gesellschaft für die Entwick...          NaN
# 3695.0  Ein modulares Sensor-Aktor-System für mobile R...          NaN
# 4020.0  Gesundheitsauswirkungen des Setting-Ansatzes i...          NaN
# 3808.0  Realisierung eines mobilen Informationsdienste...          NaN
# 3807.0  Afghanische Kultur ade- Interviewgestützte Bef...          NaN
#
#        tuhh.contributor.referee        PPN            Verfasser  \
# 3965.0           Güntner, Simon  630150826      Discher, Annika
# 3695.0              Korf, Franz  662632974  Eickhoff, Sebastian
# 4020.0           Kliche, Thomas  630155089      Richter, Sandra
# 3808.0          Mintert, Stefan  663400872      Knudsen, Martin
# 3807.0      Kübler, Hans-Dieter  66340200X   Zakarwal, Schafiqa
#
#                                                 sonstPers  \
# 3965.0  Schwarting, Frauke [Ref.]; Güntner, Simon [Ko-...
# 3695.0    Pareigis, Stephan [Ref.]; Korf, Franz [Ko-Ref.]
# 4020.0                  Färber, Christine; Kliche, Thomas
# 3808.0   Gennis, Martin [Ref.]; Mintert, Stefan [Ko-Ref.]
# 3807.0  Schmidt, Ralph [Ref.]; Kübler, Hans-Dieter [Ko...
#
#                                                     Titel  \
# 3965.0  Zur Bedeutung der Gesellschaft für die Entwick...
# 3695.0  Ein modulares Sensor-Aktor-System für mobile R...
# 4020.0  Gesundheitsauswirkungen des Setting-Ansatzes i...
# 3808.0  Realisierung eines mobilen Informationsdienste...
# 3807.0                             Afghanische Kultur ade
#
#                       RefID_plus_KoRef                        Ref  \
# 3965.0        Güntner, Simon [Ko-Ref.]  Schwarting, Frauke [Ref.]
# 3695.0           Korf, Franz [Ko-Ref.]   Pareigis, Stephan [Ref.]
# 4020.0                  Kliche, Thomas          Färber, Christine
# 3808.0       Mintert, Stefan [Ko-Ref.]      Gennis, Martin [Ref.]
# 3807.0   Kübler, Hans-Dieter [Ko-Ref.]      Schmidt, Ralph [Ref.]
#
#                   RefKopie RefID_plus_KoRefKopie
# 3965.0  Schwarting, Frauke        Güntner, Simon
# 3695.0   Pareigis, Stephan           Korf, Franz
# 4020.0   Färber, Christine        Kliche, Thomas
# 3808.0      Gennis, Martin       Mintert, Stefan
# 3807.0      Schmidt, Ralph   Kübler, Hans-Dieter

# %%
#Als neue Excel-Tabelle speichern, um prüfen zu können:
Merge2.to_excel("../data/Merge2_2.xlsx")

# %%
#Nun auch noch als CSV-Datei abspeichern:
Merge2.to_csv("../data/Merge2_2.csv")
